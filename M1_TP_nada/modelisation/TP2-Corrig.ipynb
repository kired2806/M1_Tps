# %% [markdown]
# # TP2: Ecrire comme votre auteur favori
#
# Nous allons d'abord commencer par la problématique de prédiction de mots. L'idée est d'utiliser un livre pour apprendre à la machine dans quel ordre les mots ont le plus de chance d'apparaitre.

# %% [markdown]
# ## I. Téléchargement de livres depuis Project Gutenberg (https://www.gutenberg.org)

# %%
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

#List of books along with their identifier on Project Gutenberg
# Feel free to expand the list and pick your favorite
books = { "Alice's Adventures in Wonderland": 11  , # by Lewis Carroll, 160 kb
          "The Complete Poetical Works of Edgar Allan Poe": 10031, #by Edgar Allan Poe, 400 kb
          "The Hound of the Baskervilles":    2852, # by Sir Conan Doyle, 340 kb
          "The King James Bible":             10,   # by King James, 4.3 Mb
          "The Complete Works of William Shakespeare": 100 #by William Shakespeare, 5.5 Mb
        }

def bookSelection(bookTitle):
    bookId = books[bookTitle]
    #
    print( "Loading text from Project Gutenberg URL..." )
    import urllib3
    http = urllib3.PoolManager()
    url = 'https://www.gutenberg.org/cache/epub/%s/pg%s.txt' % (bookId, bookId)
    request = http.request('GET', url)
    #
    global book
    book = request.data
    print( "Request done with %d bytes..." % len(book))
    #Converts from bytes to string
    book = book.decode("utf-8") 
    return

interact(bookSelection, bookTitle=books.keys() );
# Out:
# interactive(children=(Dropdown(description='bookTitle', options=("Alice's Adventures in Wonderland", 'The Comp…

# %%
import re #Rational expressions
words = re.split('[^A-Za-z]+', book.lower())
words = [w for w in words if w!=''] # Remove empty strings

# Computes a dictionary where keys are words
#  and values are the number of occurrences.
# Output is sorted
def generate1gram():
    gram = dict()
    
    # Populate 1-gram dictionary
    for i in range(len(words)-1):
        key = words[i]
        if gram.get(key) is None:
            gram[key] = 1
        else:
            gram[key] += 1
    
    #Warning! sorted forms a list
    gram = sorted(gram.items(), key=lambda x:-x[1])
    
    return dict(gram)

gram1 = generate1gram()

# Print length of list
print( "Total number of words, with repetition:    ", len(words) )
print( "Total number of words, without repetition: ", len(gram1) )
# Out:
# Total number of words, with repetition:     30419
# Total number of words, without repetition:  3007

# %% [markdown]
# ## II. Autocompletion avec des 1-grams

# %%
from IPython.display import display

# Information labels
infoLabel1 = widgets.Label(value="Input:")
infoLabel2 = widgets.Label(value="Last word:")
infoLabel3 = widgets.Label(value="Autocomplete suggestion:")
#Input area
inputArea = widgets.Textarea(
    value='',
    placeholder='Type something',
    description='',
    disabled=False
)
# Output labels
outputLastWord = widgets.Label(value='')
outputLabel = widgets.Label(value='')
output = widgets.Output()

def findLastWord(str):
    str = str.lower()
    str = str.rstrip()
    # Find last word
    # Hint: Use https://docs.python.org/3.7/library/stdtypes.html?highlight=rfind#str.rfind
    lastWordIndex = str.rfind( ' ', 0, len(str))
    lastWord = ''
    if lastWordIndex == -1:
        return str
    else:
        return str[(lastWordIndex+1):]   

def onChange(change):
    with output:
        lastWord = findLastWord(change.new)
        outputLastWord.value = lastWord
        #
        #Either the last word exists in the dictionary and then nothing to do
        possibleWords = [ (w,x) for (w,x) in gram1.items() if w.startswith(lastWord)]
        outputLabel.value = ''.join( [ (w+'(%d) ')%x for (w,x) in possibleWords ] )

# Sets a callback upon the change of the TextArea's content
inputArea.observe(onChange, 'value')

display( infoLabel1, output)
display( inputArea, output)
display( widgets.HBox([infoLabel2, outputLastWord]), output)
display( infoLabel3, output)
display( outputLabel, output)
# Out:
# Label(value='Input:')
# Output()
# Textarea(value='', placeholder='Type something')
# Output()
# HBox(children=(Label(value='Last word:'), Label(value='')))
# Output()
# Label(value='Autocomplete suggestion:')
# Output()
# Label(value='')
# Output()

# %% [markdown]
# ## III. Predire le mot suivant: 2-grams

# %%
# Computes a dictionary where keys are all pairs of words
#  and values are the number of occurrences.
# Output is sorted
def generate2gram():
    gram = dict()
    
    # Populate 2gram dictionary
    for i in range(len(words)-1):
        key = ( words[i], words[i+1] )
        if gram.get(key) is None:
            gram[key] = 1
        else:
            gram[key] += 1
    
    #Warning sorted forms a list
    gram = sorted(gram.items(), key=lambda x:-x[1])
    
    return dict(gram)

# %%
#Test
gram2 = generate2gram()
print( [(w,x) for (w,x) in gram2.items() if x>50] )
# Out:
# [(('said', 'the'), 210), (('of', 'the'), 159), (('said', 'alice'), 116), (('in', 'a'), 101), (('in', 'the'), 95), (('project', 'gutenberg'), 87), (('and', 'the'), 85), (('to', 'the'), 85), (('it', 'was'), 76), (('the', 'queen'), 72), (('at', 'the'), 63), (('the', 'king'), 62), (('as', 'she'), 61), (('don', 't'), 61), (('she', 'had'), 60), (('i', 'm'), 59), (('a', 'little'), 59), (('it', 's'), 57), (('gutenberg', 'tm'), 57), (('mock', 'turtle'), 56), (('she', 'was'), 55), (('and', 'she'), 55), (('to', 'be'), 54), (('the', 'mock'), 53), (('the', 'gryphon'), 53), (('the', 'hatter'), 52), (('with', 'the'), 51)]

# %%
gram1.items()
# Out:
# dict_items([('the', 1818), ('and', 940), ('to', 809), ('a', 690), ('of', 631), ('it', 610), ('she', 553), ('i', 545), ('you', 481), ('said', 462), ('in', 431), ('alice', 403), ('was', 358), ('that', 330), ('as', 274), ('her', 248), ('with', 228), ('at', 227), ('s', 219), ('t', 218), ('on', 204), ('all', 200), ('this', 181), ('for', 179), ('had', 178), ('but', 175), ('be', 167), ('not', 166), ('or', 155), ('they', 155), ('so', 152), ('very', 145), ('what', 142), ('is', 135), ('little', 128), ('he', 128), ('out', 118), ('if', 116), ('one', 106), ('up', 103), ('down', 102), ('about', 102), ('there', 101), ('no', 100), ('do', 98), ('his', 96), ('then', 94), ('gutenberg', 93), ('them', 88), ('know', 88), ('project', 87), ('have', 85), ('like', 85), ('were', 85), ('would', 83), ('went', 83), ('again', 83), ('herself', 83), ('when', 80), ('by', 78), ('could', 78), ('any', 76), ('queen', 75), ('thought', 74), ('off', 73), ('are', 73), ('can', 73), ('how', 72), ('time', 71), ('your', 71), ('see', 70), ('me', 68), ('into', 67), ('who', 66), ('well', 63), ('did', 63), ('its', 63), ('m', 63), ('king', 63), ('an', 61), ('don', 61), ('now', 60), ('turtle', 59), ('way', 58), ('began', 58), ('my', 58), ('ll', 57), ('tm', 57), ('which', 56), ('hatter', 56), ('mock', 56), ('quite', 55), ('gryphon', 55), ('must', 54), ('other', 54), ('think', 53), ('work', 53), ('much', 52), ('just', 52), ('some', 52), ('their', 52), ('only', 52), ('rabbit', 51), ('say', 51), ('first', 51), ('here', 51), ('from', 51), ('head', 50), ('go', 50), ('more', 50), ('thing', 49), ('never', 48), ('voice', 48), ('such', 47), ('come', 47), ('get', 46), ('oh', 45), ('looked', 45), ('got', 45), ('ve', 44), ('mouse', 44), ('after', 43), ('we', 43), ('him', 43), ('duchess', 42), ('round', 41), ('re', 40), ('over', 40), ('before', 40), ('why', 40), ('came', 40), ('will', 40), ('two', 40), ('tone', 40), ('dormouse', 40), ('great', 39), ('back', 39), ('been', 38), ('cat', 37), ('right', 36), ('march', 35), ('found', 35), ('last', 34), ('nothing', 34), ('once', 34), ('without', 34), ('large', 33), ('things', 33), ('long', 33), ('works', 33), ('tell', 32), ('looking', 32), ('use', 31), ('moment', 31), ('put', 31), ('hare', 31), ('made', 30), ('white', 30), ('next', 30), ('make', 30), ('door', 30), ('heard', 30), ('d', 30), ('day', 29), ('eyes', 29), ('dear', 29), ('look', 29), ('should', 29), ('replied', 29), ('e', 29), ('may', 28), ('away', 28), ('upon', 28), ('might', 28), ('three', 28), ('caterpillar', 28), ('shall', 27), ('seemed', 27), ('going', 27), ('good', 27), ('poor', 27), ('course', 27), ('electronic', 27), ('too', 26), ('than', 26), ('while', 26), ('won', 26), ('rather', 25), ('soon', 25), ('same', 25), ('yet', 25), ('foundation', 25), ('took', 24), ('sure', 24), ('felt', 23), ('half', 23), ('added', 23), ('under', 22), ('terms', 22), ('getting', 22), ('take', 22), ('another', 22), ('anything', 22), ('let', 22), ('please', 22), ('wish', 22), ('set', 22), ('jury', 22), ('even', 21), ('words', 21), ('hand', 21), ('ever', 21), ('however', 21), ('find', 21), ('minute', 21), ('till', 21), ('old', 21), ('end', 20), ('sort', 20), ('cried', 20), ('feet', 19), ('tried', 19), ('tea', 19), ('curious', 19), ('being', 19), ('full', 19), ('wonder', 18), ('house', 18), ('eat', 18), ('table', 18), ('enough', 18), ('something', 18), ('where', 18), ('soup', 18), ('court', 18), ('agreement', 18), ('spoke', 17), ('perhaps', 17), ('talking', 17), ('question', 17), ('side', 17), ('sat', 17), ('these', 17), ('asked', 17), ('bill', 17), ('give', 16), ('license', 16), ('ran', 16), ('through', 16), ('people', 16), ('am', 16), ('bit', 16), ('turned', 16), ('high', 16), ('garden', 16), ('indeed', 16), ('because', 16), ('hastily', 16), ('doesn', 16), ('used', 16), ('both', 16), ('beginning', 15), ('hear', 15), ('seen', 15), ('near', 15), ('idea', 15), ('air', 15), ('saying', 15), ('low', 15), ('knew', 15), ('face', 15), ('gave', 15), ('speak', 15), ('done', 15), ('change', 15), ('called', 15), ('us ...

# %%
from IPython.display import display

# Information labels
infoLabel1 = widgets.Label(value="Input:")
infoLabel2 = widgets.Label(value="Autocomplete suggestions:")
infoLabel3 = widgets.Label(value="Suggestion from word prediction:")
#Input area
inputArea = widgets.Textarea(
    value='',
    placeholder='Type something',
    description='',
    disabled=False
)
# Output labels
outputAutocomplete = widgets.Label(value='')
outputPrediction = widgets.Label(value='')
output = widgets.Output()

def onChange(change):
    with output:
        lastWord = findLastWord( change.new )
        #
        # Autocomplete as before
        possibleWords = [ (w,x) for (w,x) in gram1.items() if w.startswith(lastWord)]
        outputAutocomplete.value = ''.join( [ w+'(%d) '%x for (w,x) in possibleWords ] )
        #
        # Prediction
        # Either the last word does not exist in the dictionary (or equivalently the 1-gram) and then nothing to do
        if lastWord not in [w for (w,x) in possibleWords]:
            outputPrediction.value = ''
        # or the last word allows to predict the next
        else:
            possiblePairs = predictNextWord(lastWord)
            outputPrediction.value = ''.join( [ (p[1]+'(%d) ') % x for (p,x) in possiblePairs ] )
        
def predictNextWord(str):
    return [ i for i in gram2.items() if str==i[0][0]]

# Sets a callback upon the change of the TextArea's content
inputArea.observe(onChange, 'value')

display( widgets.HBox( [infoLabel1, inputArea] ) , output)
display( infoLabel2, output)
display( outputAutocomplete, output)
display( infoLabel3, output )
display( outputPrediction, output)
# Out:
# HBox(children=(Label(value='Input:'), Textarea(value='', placeholder='Type something')))
# Output()
# Label(value='Autocomplete suggestions:')
# Output()
# Label(value='')
# Output()
# Label(value='Suggestion from word prediction:')
# Output()
# Label(value='')
# Output()

# %% [markdown]
# # III. N-Grams (tri-grams and more...)

# %%
def generateNgram(n=1):
    gram = dict()
    
    # Some helpers to keep us from crashing the PC for now
    assert n > 0 and n < 100
    
    # Populate N-gram dictionary
    for i in range(len(words)-(n-1)):
        key = tuple(words[i:i+n])
        if gram.get(key) is None:
            gram[key] = 1
        else:
            gram[key] += 1
            
    #Warning sorted forms a list
    gram = sorted(gram.items(), key=lambda x:-x[1])
    return dict(gram)

# %%
# Test
gram5 = generateNgram(5)
print( [(w,x) for (w,x) in gram5.items() if x>10] )
# Out:
# [(('the', 'project', 'gutenberg', 'literary', 'archive'), 13), (('project', 'gutenberg', 'literary', 'archive', 'foundation'), 13), (('project', 'gutenberg', 'tm', 'electronic', 'works'), 12)]

# %%
maxLag = 5
Ngrams = []
for i in range(1,maxLag):
    Ngrams.append( generateNgram(i))
Ngrams.reverse()
print( "Generated Ngrams for N from 1 to ", len(Ngrams) )
# Out:
# Generated Ngrams for N from 1 to  4

# %%
Ngrams[0]
# Out:
# {('said', 'the', 'mock', 'turtle'): 19,
#  ('project', 'gutenberg', 'tm', 'electronic'): 18,
#  ('she', 'said', 'to', 'herself'): 16,
#  ('the', 'project', 'gutenberg', 'tm'): 13,
#  ('the', 'project', 'gutenberg', 'literary'): 13,
#  ('project', 'gutenberg', 'literary', 'archive'): 13,
#  ('gutenberg', 'literary', 'archive', 'foundation'): 13,
#  ('gutenberg', 'tm', 'electronic', 'works'): 12,
#  ('a', 'minute', 'or', 'two'): 11,
#  ('you', 'won', 't', 'you'): 10,
#  ('terms', 'of', 'this', 'agreement'): 9,
#  ('said', 'the', 'march', 'hare'): 8,
#  ('will', 'you', 'won', 't'): 8,
#  ('project', 'gutenberg', 'tm', 'license'): 8,
#  ('the', 'terms', 'of', 'this'): 8,
#  ('of', 'project', 'gutenberg', 'tm'): 8,
#  ('of', 'the', 'project', 'gutenberg'): 7,
#  ('said', 'alice', 'in', 'a'): 7,
#  ('i', 'don', 't', 'know'): 7,
#  ('to', 'the', 'project', 'gutenberg'): 7,
#  ('alice', 's', 'adventures', 'in'): 6,
#  ('s', 'adventures', 'in', 'wonderland'): 6,
#  ('as', 'well', 'as', 'she'): 6,
#  ('well', 'as', 'she', 'could'): 6,
#  ('in', 'a', 'great', 'hurry'): 6,
#  ('in', 'a', 'tone', 'of'): 6,
#  ('the', 'moral', 'of', 'that'): 6,
#  ('moral', 'of', 'that', 'is'): 6,
#  ('won', 't', 'you', 'will'): 6,
#  ('t', 'you', 'will', 'you'): 6,
#  ('the', 'full', 'project', 'gutenberg'): 6,
#  ('full', 'project', 'gutenberg', 'tm'): 6,
#  ('gutenberg', 'tm', 'electronic', 'work'): 6,
#  ('out', 'of', 'the', 'way'): 5,
#  ('i', 've', 'got', 'to'): 5,
#  ('the', 'little', 'golden', 'key'): 5,
#  ('the', 'poor', 'little', 'thing'): 5,
#  ('as', 'she', 'said', 'this'): 5,
#  ('she', 'said', 'this', 'she'): 5,
#  ('i', 'beg', 'your', 'pardon'): 5,
#  ('said', 'the', 'duchess', 'and'): 5,
#  ('said', 'the', 'king', 'and'): 5,
#  ('and', 'the', 'moral', 'of'): 5,
#  ('in', 'the', 'united', 'states'): 5,
#  ('a', 'project', 'gutenberg', 'tm'): 5,
#  ('project', 'gutenberg', 'tm', 'works'): 5,
#  ('project', 'gutenberg', 'tm', 'work'): 5,
#  ('the', 'terms', 'of', 'the'): 4,
#  ('as', 'she', 'could', 'for'): 4,
#  ('she', 'did', 'not', 'like'): 4,
#  ('did', 'not', 'like', 'to'): 4,
#  ('she', 'came', 'upon', 'a'): 4,
#  ('there', 'seemed', 'to', 'be'): 4,
#  ('seemed', 'to', 'be', 'no'): 4,
#  ('said', 'alice', 'to', 'herself'): 4,
#  ('and', 'when', 'she', 'had'): 4,
#  ('i', 'm', 'sure', 'i'): 4,
#  ('wish', 'i', 'hadn', 't'): 4,
#  ('i', 'should', 'like', 'to'): 4,
#  ('i', 'm', 'afraid', 'i'): 4,
#  ('if', 'you', 'don', 't'): 4,
#  ('in', 'an', 'offended', 'tone'): 4,
#  ('i', 'don', 't', 'think'): 4,
#  ('so', 'she', 'went', 'on'): 4,
#  ('out', 'of', 'its', 'mouth'): 4,
#  ('said', 'the', 'caterpillar', 'well'): 4,
#  ('for', 'a', 'minute', 'or'): 4,
#  ('every', 'now', 'and', 'then'): 4,
#  ('at', 'the', 'top', 'of'): 4,
#  ('like', 'the', 'look', 'of'): 4,
#  ('the', 'end', 'of', 'the'): 4,
#  ('the', 'march', 'hare', 'said'): 4,
#  ('is', 'the', 'same', 'thing'): 4,
#  ('off', 'with', 'his', 'head'): 4,
#  ('at', 'the', 'bottom', 'of'): 4,
#  ('in', 'a', 'low', 'voice'): 4,
#  ('please', 'your', 'majesty', 'said'): 4,
#  ('off', 'with', 'her', 'head'): 4,
#  ('the', 'king', 'and', 'the'): 4,
#  ('a', 'tone', 'of', 'great'): 4,
#  ('the', 'mock', 'turtle', 'said'): 4,
#  ('join', 'the', 'dance', 'will'): 4,
#  ('the', 'dance', 'will', 'you'): 4,
#  ('dance', 'will', 'you', 'won'): 4,
#  ('you', 'will', 'you', 'won'): 4,
#  ('you', 'join', 'the', 'dance'): 4,
#  ('would', 'not', 'could', 'not'): 4,
#  ('beau', 'ootiful', 'soo', 'oop'): 4,
#  ('the', 'king', 'said', 'to'): 4,
#  ('said', 'the', 'white', 'rabbit'): 4,
#  ('this', 'work', 'or', 'any'): 4,
#  ('the', 'phrase', 'project', 'gutenberg'): 4,
#  ('project', 'gutenberg', 'tm', 'trademark'): 4,
#  ('for', 'the', 'use', 'of'): 3,
#  ('terms', 'of', 'the', 'project'): 3,
#  ('of', 'this', 'project', 'gutenberg'): 3,
#  ('and', 'looked', 'at', 'it'): 3,
#  ('just', 'in', 'time', 'to'): 3,
#  ('there', 'was', 'no', 'one'): 3,
#  ('i', 'wonder', 'if', 'i'): 3,
#  ('do', 'cats', 'eat', 'bats'): 3,
#  ('to', 'one', 'of', 'the'): 3,
#  ('but', 'she', 'could', 'not'): 3,
#  ('went', 'back', 'to', 'the'): 3,
#  ('to', 'see', 'if', 'she'): 3,
#  ('little', 'golden', 'key', 'and'): 3,
#  ('there', 's', 'no', 'use'): 3,
#  ('it', 's', 'no', 'use'): 3,
#  ('to', 'find', 'that', 'she'): 3,
#  ('she', 'set', 'to', 'work'): 3,
#  ('and', 'she', 'went', 'on'): 3,
#  ('she', 'heard', 'a', 'little'): 3,
#  ('a', 'little', 'pattering', 'of'): 3,
#  ('in', 'the', 'distance', 'and'): 3,
#  ('was', 'the', 'white', 'rabbit'): 3,
#  ('in', 'one', 'hand', 'and'): 3,
#  ('one', 'hand', 'and', 'a'): 3,
#  ('began', 'in', 'a', 'low'): 3,
#  ('how', 'doth', 'the', 'little'): 3,
#  ('said', 'alice', 'as', 'she'): 3,
#  ('oh', 'i', 'beg', 'your'): 3,
#  ('to', 'herself', 'as', 'she'): 3,
#  ('to', 'change', 'the', 'subject'): 3,
#  ('i', 'can', 't', 'remember'): 3,
#  ('you', 'did', 'said', 'the'): 3,
#  ('i', 'don', 't', 'believe'): 3,
#  ('as', 'she', 'could', 'the'): 3,
#  ('in', 'a', 'trembling', 'voice'): 3,
#  ('i', 'don', 't', 'like'): 3,
#  ('alice', 'thought', 'to', 'herself'): 3,
#  ('thought', 'to', 'herself', 'i'): 3,
#  ('said', 'to', 'herself', 'and'): 3,
#  ('of', 'its', 'mouth', 'and'): 3,
#  ('she', 'might', 'as', 'well'): 3,
#  ('was', 'sitting', 'on', 'the'): 3,
#  ('took', 'the', 'hookah', 'out'): 3,
#  ('the', 'hookah', 'out', 'of'): 3,
#  ('hookah', 'out', 'of', 'its'): 3,
#  ('i', 'don', 't', 'see'): 3,
#  ('said', 'the', 'caterpillar', 'alice'): 3,
#  ('you', 'are', 'old', 'father'): 3,
#  ('are', 'old', 'father', 'william'): 3,
#  ('you', 'are', 'old', 'said'): 3,
#  ('are', 'old', 'said', 'the'): 3,
#  ('old', 'said', 'the', 'youth'): 3,
#  ('but', 'i', 'm', 'not'): 3,
#  ('the', 'other', 'side', 'of'): 3,
#  ('was', 'out', 'of', 'sight'): 3,
#  ('and', 'was', 'going', 'to'): 3,
#  ('i', 'm', 'not', 'a'): 3,
#  ('said', 'alice', 'i', 've'): 3,
#  ('minute', 'or', 'two', 'she'): 3,
#  ('how', 'am', 'i', 'to'): 3,
#  ('am', 'i', 'to', 'get'): 3,
#  ('i', 'to', 'get', 'in'): 3,
#  ('at', 'all', 'said', 'the'): 3,
#  ('you', 'like', 'said', 'the'): 3,
#  ('would', 'you', 'tell', 'me'): 3,
#  ('said', 'alice', 'a', 'little'): 3,
#  ('alice', 'a', 'little', 'timidly'): 3,
#  ('i', 'didn', 't', 'know'): 3,
#  ('you', 'don', 't', 'know'): 3,
#  ('the', 'duchess', 'and', 'the'): 3,
#  ('at', 'the', 'end', 'of'): 3,
#  ('it', 'would', 'be', 'quite'): 3,
#  ('said', 'the', 'cat', 'i'): 3,
#  ('it', 'doesn', 't', 'matter'): 3,
#  ('but', 'i', 'don', 't'): 3,
#  ('said', 'the', 'cat', 'and'): 3,
#  ('said', 'the', 'hatter', 'you'): 3,
#  ('you', 'might', 'just', 'as'): 3,
#  ('might', 'just', 'as', 'well'): 3,
#  ('just', 'as', 'well', 'say'): 3,
#  ('the', 'same', 'thing', 'as'): 3,
#  ('same', 'thing', 'as', 'i'): 3,
#  ('at', 'the', 'march', 'hare'): 3,
#  ('of', 'meaning', 'in', 'it'): 3,
#  ('don', 't', 'know', 'what'): 3,
#  ('the', 'hatter', 'went', 'on'): 3,
#  ('went', 'on', 'in', 'a'): 3,
#  ('he', 'said', 'in', 'a'): 3,
#  ('the', 'bottom', 'of', 'a'): 3,
#  ('bottom', 'of', 'a', 'well'): 3,
#  ('as', 'he', 'spoke', 'and'): 3,
#  ('the', 'knave', 'of', 'hearts'): 3,
#  ('the', 'rest', 'of', 'the'): 3,
#  ('the', 'game', 'the', 'queen'): 3,
#  ('s', 'argument', 'was', 'that'): 3,
#  ('go', 'on', 'with', 'the'): 3,
#  ('the', 'mock', 'turtle', 'and'): 3,
#  ('the', 'mock', 'turtle', 'in'): 3,
#  ('the', 'gryphon', 'and', 'the'): 3,
#  ('to', 'the', 'mock', 'turtle'): 3,
#  ('the', 'mock', 'turtle', 'went'): 3,
#  ('mock', 'turtle', 'went', 'on'): 3,
#  ('we', 'went', 'to', 'school'): 3,
#  ('the', 'mock', 'turtle', 'replied'): 3,
#  ('the', 'gryphon', 'went', 'on'): 3,
#  ('said', 'the', 'gryphon', 'i'): 3,
#  ('not', 'join', 'the', 'dance'): 3,
#  ('not', 'could', 'not', 'would'): 3,
#  ('could', 'not', 'would', 'not'): 3,
#  ('he', 'said', 'to', 'the'): 3,
#  ('the', 'voice', 'of', 'the'): 3,
#  ('soo', 'oop', 'of', 'the'): 3,
#  ('oop', 'of', 'the', 'e'): 3,
#  ('of', 'the', 'e', 'e'): 3,
#  ('the', 'e', 'e', 'evening'): 3,
#  ('e', 'e', 'evening', 'beautiful'): 3,
#  ('king', 'said', 'to', 'the'): 3,
#  ('said', 'to', 'the', 'jury'): 3,
#  ('or', 'i', 'll', 'have'): 3,
#  ('i', 'll', 'have', 'you'): 3,
#  ('ll', 'have', 'you', 'executed'): 3,
#  ('the', 'officers', 'of', 'the'): 3,
#  ('officers', 'of', 'the', 'court'): 3,
#  ('i', 'm', 'a', 'poor'): 3,
#  ('m', 'a', 'poor', 'man'): 3,
#  ('it', 'said', 'the', 'king'): 3,
#  ('said', 'the', 'king', 'the'): 3,
#  ('and', 'how', 'she', 'would'): 3,
#  ('work', 'or', 'any', 'other'): 3,
#  ('all', 'the', 'terms', 'of'): 3,
#  ('copies', 'of', 'project', 'gutenberg'): 3,
#  ('the', 'person', 'or', 'entity'): 3,
#  ('as', 'set', 'forth', 'in'): 3,
#  ('set', 'forth', 'in', 'paragraph'): 3,
#  ('you', 'can', 'do', 'with'): 3,
#  ('literary', 'archive', 'foundation', 'the'): 3,
#  ('public', 'domain', 'in', 'the'): 3,
#  ('outside', 'the', 'united', 'states'): 3,
#  ('permission', 'of', 'the', 'copyright'): 3,
#  ('of', 'the', 'copyright', 'holder'): 3,
#  ('any', 'project', 'gutenberg', 'tm'): 3,
#  ('the', 'owner', 'of', 'the'): 3,
#  ('owner', 'of', 'the', 'project'): 3,
#  ('donations', 'to', 'the', 'project'): 3,
#  ('right', 'of', 'replacement', 'or'): 3,
#  ('of', 'replacement', 'or', 'refund'): 3,
#  ('you', 'received', 'the', 'work'): 3,
#  ('project', 'gutenberg', 's', 'alice'): 2,
#  ('gutenberg', 's', 'alice', 's'): 2,
#  ('s', 'alice', 's', 'adventures'): 2,
#  ('adventures', 'in', 'wonderland', 'by'): 2,
#  ('in', 'wonderland', 'by', 'lewis'): 2,
#  ('wonderland', 'by', 'lewis', 'carroll'): 2,
#  ('this', 'ebook', 'is', 'for'): 2,
#  ('ebook', 'is', 'for', 'the'): 2,
#  ('is', 'for', 'the', 'use'): 2,
#  ('the', 'use', 'of', 'anyone'): 2,
#  ('use', 'of', 'anyone', 'anywhere'): 2,
#  ('of', 'anyone', 'anywhere', 'at'): 2,
#  ('anyone', 'anywhere', 'at', 'no'): 2,
#  ('anywhere', 'at', 'no', 'cost'): 2,
#  ('at', 'no', 'cost', 'and'): 2,
#  ('no', 'cost', 'and', 'with'): 2,
#  ('cost', 'and', 'with', 'almost'): 2,
#  ('and', 'with', 'almost', 'no'): 2,
#  ('with', 'almost', 'no', 'restrictions'): 2,
#  ('almost', 'no', 'restrictions', 'whatsoever'): 2,
#  ('no', 'restrictions', 'whatsoever', 'you'): 2,
#  ('restrictions', 'whatsoever', 'you', 'may'): 2,
#  ('whatsoever', 'you', 'may', 'copy'): 2,
#  ('you', 'may', 'copy', 'it'): 2,
#  ('may', 'copy', 'it', 'give'): 2,
#  ('copy', 'it', 'give', 'it'): 2,
#  ('it', 'give', 'it', 'away'): 2,
#  ('give', 'it', 'away', 'or'): 2,
#  ('it', 'away', 'or', 're'): 2,
#  ('away', 'or', 're', 'use'): 2,
#  ('or', 're', 'use', 'it'): 2,
#  ('re', 'use', 'it', 'under'): 2,
#  ('use', 'it', 'under', 'the'): 2,
#  ('it', 'under', 'the', 'terms'): 2,
#  ('under', 'the', 'terms', 'of'): 2,
#  ('the', 'project', 'gutenberg', 'license'): 2,
#  ('project', 'gutenberg', 'license', 'included'): 2,
#  ('gutenberg', 'license', 'included', 'with'): 2,
#  ('license', 'included', 'with', 'this'): 2,
#  ('included', 'with', 'this', 'ebook'): 2,
#  ('with', 'this', 'ebook', 'or'): 2,
#  ('this', 'ebook', 'or', 'online'): 2,
#  ('ebook', 'or', 'online', 'at'): 2,
#  ('or', 'online', 'at', 'www'): 2,
#  ('online', 'at', 'www', 'gutenberg'): 2,
#  ('at', 'www', 'gutenberg', 'org'): 2,
#  ('this', 'project', 'gutenberg', 'ebook'): 2,
#  ('project', 'gutenberg', 'ebook', 'alice'): 2,
#  ('gutenberg', 'ebook', 'alice', 's'): 2,
#  ('ebook', 'alice', 's', 'adventures'): 2,
#  ('what', 'is', 'the', 'use'): 2,
#  ('is', 'the', 'use', 'of'): 2,
#  ('the', 'use', 'of', 'a'): 2,
#  ('she', 'could', 'for', 'the'): 2,
#  ('oh', 'dear', 'i', 'shall'): 2,
#  ('she', 'thought', 'it', 'over'): 2,
#  ('it', 'occurred', 'to', 'her'): 2,
#  ('occurred', 'to', 'her', 'that'): 2,
#  ('to', 'her', 'that', 'she'): 2,
#  ('was', 'just', 'in', 'time'): 2,
#  ('to', 'get', 'out', 'again'): 2,
#  ('not', 'a', 'moment', 'to'): 2,
#  ('but', 'it', 'was', 'too'): 2,
#  ('thought', 'alice', 'to', 'herself'): 2,
#  ('by', 'this', 'time', 'she'): 2,
#  ('this', 'time', 'she', 'said'): 2,
#  ('to', 'listen', 'to', 'her'): 2,
#  ('alice', 'had', 'no', 'idea'): 2,
#  ('had', 'no', 'idea', 'what'): 2,
#  ('wonder', 'if', 'i', 'shall'): 2,
#  ('how', 'funny', 'it', 'll'): 2,
#  ('funny', 'it', 'll', 'seem'): 2,
#  ('i', 'shall', 'have', 'to'): 2,
#  ('and', 'she', 'tried', 'to'): 2,
#  ('it', 'll', 'never', 'do'): 2,
#  ('ll', 'never', 'do', 'to'): 2,
#  ('nothing', 'else', 'to', 'do'): 2,
#  ('my', 'dear', 'i', 'wish'): 2,
#  ('dear', 'i', 'wish', 'you'): 2,
#  ('to', 'herself', 'in', 'a'): 2,
#  ('for', 'you', 'see', 'as'): 2,
#  ('she', 'felt', 'that', 'she'): 2,
#  ('felt', 'that', 'she', 'was'): 2,
#  ('and', 'had', 'just', 'begun'): 2,
#  ('had', 'just', 'begun', 'to'): 2,
#  ('and', 'she', 'jumped', 'up'): 2,
#  ('and', 'the', 'white', 'rabbit'): 2,
#  ('she', 'found', 'herself', 'in'): 2,
#  ('there', 'was', 'nothing', 'on'): 2,
#  ('was', 'nothing', 'on', 'it'): 2,
#  ('but', 'at', 'any', 'rate'): 2,
#  ('opened', 'the', 'door', 'and'): 2,
#  ('of', 'very', 'little', 'use'): 2,
#  ('i', 'wish', 'i', 'could'): 2,
#  ('up', 'like', 'a', 'telescope'): 2,
#  ('of', 'the', 'way', 'things'): 2,
#  ('she', 'went', 'back', 'to'): 2,
#  ('back', 'to', 'the', 'table'): 2,
#  ('with', 'the', 'words', 'drink'): 2,
#  ('the', 'words', 'drink', 'me'): 2,
#  ('at', 'the', 'thought', 'that'): 2,
#  ('that', 'she', 'was', 'now'): 2,
#  ('into', 'that', 'lovely', 'garden'): 2,
#  ('a', 'little', 'nervous', 'about'): 2,
#  ('you', 'know', 'said', 'alice'): 2,
#  ('she', 'could', 'not', 'remember'): 2,
#  ('could', 'not', 'remember', 'ever'): 2,
#  ('not', 'remember', 'ever', 'having'): 2,
#  ('she', 'got', 'to', 'the'): 2,
#  ('s', 'no', 'use', 'in'): 2,
#  ('into', 'her', 'eyes', 'and'): 2,
#  ('to', 'be', 'two', 'people'): 2,
#  ('but', 'it', 's', 'no'): 2,
#  ('why', 'there', 's', 'hardly'): 2,
#  ('and', 'if', 'it', 'makes'): 2,
#  ('if', 'it', 'makes', 'me'): 2,
#  ('it', 'makes', 'me', 'grow'): 2,
#  ('and', 'i', 'don', 't'): 2,
#  ('on', 'the', 'top', 'of'): 2,
#  ('the', 'top', 'of', 'her'): 2,
#  ('of', 'her', 'head', 'to'): 2,
#  ('and', 'she', 'was', 'quite'): 2,
#  ('so', 'she', 'set', 'to'): 2,
#  ('the', 'pool', 'of', 'tears'): 2,
#  ('when', 'she', 'looked', 'down'): 2,
#  ('she', 'looked', 'down', 'at'): 2,
#  ('looked', 'down', 'at', 'her'): 2,
#  ('but', 'i', 'must', 'be'): 2,
#  ('the', 'roof', 'of', 'the'): 2,
#  ('it', 'was', 'as', 'much'): 2,
#  ('was', 'as', 'much', 'as'): 2,
#  ('as', 'much', 'as', 'she'): 2,
#  ('much', 'as', 'she', 'could'): 2,
#  ('as', 'she', 'could', 'do'): 2,
#  ('began', 'to', 'cry', 'again'): 2,
#  ('you', 'ought', 'to', 'be'): 2,
#  ('ought', 'to', 'be', 'ashamed'): 2,
#  ('to', 'be', 'ashamed', 'of'): 2,
#  ('be', 'ashamed', 'of', 'yourself'): 2,
#  ('there', 'was', 'a', 'large'): 2,
#  ('heard', 'a', 'little', 'pattering'): 2,
#  ('little', 'pattering', 'of', 'feet'): 2,
#  ('the', 'distance', 'and', 'she'): 2,
#  ('to', 'see', 'what', 'was'): 2,
#  ('it', 'was', 'the', 'white'): 2,
#  ('pair', 'of', 'white', 'kid'): 2,
#  ('of', 'white', 'kid', 'gloves'): 2,
#  ('the', 'duchess', 'the', 'duchess'): 2,
#  ('duchess', 'the', 'duchess', 'oh'): 2,
#  ('white', 'kid', 'gloves', 'and'): 2,
#  ('took', 'up', 'the', 'fan'): 2,
#  ('up', 'the', 'fan', 'and'): 2,
#  ('the', 'fan', 'and', 'gloves'): 2,
#  ('when', 'i', 'got', 'up'): 2,
#  ('i', 'got', 'up', 'this'): 2,
#  ('got', 'up', 'this', 'morning'): 2,
#  ('and', 'she', 'began', 'thinking'): 2,
#  ('she', 'began', 'thinking', 'over'): 2,
#  ('have', 'been', 'changed', 'for'): 2,
#  ('and', 'i', 'm', 'sure'): 2,
#  ('all', 'sorts', 'of', 'things'): 2,
#  ('is', 'the', 'capital', 'of'): 2,
#  ('i', 'must', 'have', 'been'): 2,
#  ('must', 'have', 'been', 'changed'): 2,
#  ('say', 'how', 'doth', 'the'): 2,
#  ('as', 'if', 'she', 'were'): 2,
#  ('and', 'began', 'to', 'repeat'): 2,
#  ('began', 'to', 'repeat', 'it'): 2,
#  ('to', 'repeat', 'it', 'but'): 2,
#  ('repeat', 'it', 'but', 'her'): 2,
#  ('as', 'she', 'went', 'on'): 2,
#  ('i', 'll', 'stay', 'down'): 2,
#  ('ll', 'stay', 'down', 'here'): 2,
#  ('oh', 'dear', 'cried', 'alice'): 2,
#  ('said', 'this', 'she', 'looked'): 2,
#  ('she', 'got', 'up', 'and'): 2,
#  ('she', 'was', 'now', 'about'): 2,
#  ('about', 'two', 'feet', 'high'): 2,
#  ('a', 'good', 'deal', 'frightened'): 2,
#  ('very', 'glad', 'to', 'find'): 2,
#  ('i', 'never', 'was', 'so'): 2,
#  ('and', 'in', 'another', 'moment'): 2,
#  ('was', 'that', 'she', 'had'): 2,
#  ('she', 'soon', 'made', 'out'): 2,
#  ('soon', 'made', 'out', 'that'): 2,
#  ('i', 'wish', 'i', 'hadn'): 2,
#  ('about', 'in', 'the', 'pool'): 2,
#  ('out', 'what', 'it', 'was'): 2,
#  ('she', 'thought', 'it', 'must'): 2,
#  ('thought', 'it', 'must', 'be'): 2,
#  ('it', 'must', 'be', 'a'): 2,
#  ('must', 'be', 'the', 'right'): 2,
#  ('such', 'a', 'thing', 'before'): 2,
#  ('beg', 'your', 'pardon', 'cried'): 2,
#  ('your', 'pardon', 'cried', 'alice'): 2,
#  ('i', 'think', 'you', 'd'): 2,
#  ('she', 'is', 'such', 'a'): 2,
#  ('in', 'the', 'pool', 'and'): 2,
#  ('is', 'such', 'a', 'nice'): 2,
#  ('and', 'she', 's', 'such'): 2,
#  ('she', 's', 'such', 'a'): 2,
#  ('s', 'such', 'a', 'capital'): 2,
#  ('such', 'a', 'capital', 'one'): 2,
#  ('a', 'capital', 'one', 'for'): 2,
#  ('capital', 'one', 'for', 'catching'): 2,
#  ('one', 'for', 'catching', 'mice'): 2,
#  ('we', 'won', 't', 'talk'): 2,
#  ('won', 't', 'talk', 'about'): 2,
#  ('hurry', 'to', 'change', 'the'): 2,
#  ('the', 'mouse', 'did', 'not'): 2,
#  ('alice', 'went', 'on', 'eagerly'): 2,
#  ('in', 'a', 'sorrowful', 'tone'): 2,
#  ('and', 'making', 'quite', 'a'): 2,
#  ('don', 't', 'like', 'them'): 2,
#  ('said', 'in', 'a', 'low'): 2,
#  ('in', 'a', 'low', 'trembling'): 2,
#  ('a', 'low', 'trembling', 'voice'): 2,
#  ('and', 'the', 'whole', 'party'): 2,
#  ('after', 'a', 'few', 'minutes'): 2,
#  ('as', 'if', 'she', 'had'): 2,
#  ('who', 'seemed', 'to', 'be'): 2,
#  ('she', 'did', 'not', 'get'): 2,
#  ('edwin', 'and', 'morcar', 'the'): 2,
#  ('and', 'morcar', 'the', 'earls'): 2,
#  ('morcar', 'the', 'earls', 'of'): 2,
#  ('the', 'earls', 'of', 'mercia'): 2,
#  ('earls', 'of', 'mercia', 'and'): 2,
#  ('of', 'mercia', 'and', 'northumbria'): 2,
#  ('beg', 'your', 'pardon', 'said'): 2,
#  ('of', 'course', 'you', 'know'): 2,
#  ('course', 'you', 'know', 'what'): 2,
#  ('know', 'what', 'it', 'means'): 2,
#  ('how', 'are', 'you', 'getting'): 2,
#  ('are', 'you', 'getting', 'on'): 2,
#  ('in', 'a', 'melancholy', 'tone'): 2,
#  ('some', 'of', 'the', 'other'): 2,
#  ('what', 'i', 'was', 'going'): 2,
#  ('i', 'was', 'going', 'to'): 2,
#  ('half', 'an', 'hour', 'or'): 2,
#  ('an', 'hour', 'or', 'so'): 2,
#  ('they', 'all', 'crowded', 'round'): 2,
#  ('in', 'silence', 'at', 'last'): 2,
#  ('silence', 'at', 'last', 'the'): 2,
#  ('that', 'she', 'did', 'not'): 2,
#  ('did', 'not', 'dare', 'to'): 2,
#  ('could', 'not', 'think', 'of'): 2,
#  ('it', 'was', 'over', 'at'): 2,
#  ('was', 'over', 'at', 'last'): 2,
#  ('over', 'at', 'last', 'and'): 2,
#  ('she', 'added', 'in', 'a'): 2,
#  ('that', 'it', 'would', 'be'): 2,
#  ('said', 'the', 'mouse', 'to'): 2,
#  ('and', 'looking', 'anxiously', 'about'): 2,
#  ('nothing', 'of', 'the', 'sort'): 2,
#  ('of', 'the', 'sort', 'said'): 2,
#  ('getting', 'up', 'and', 'walking'): 2,
#  ('it', 'pleaded', 'poor', 'alice'): 2,
#  ('so', 'easily', 'offended', 'you'): 2,
#  ('shook', 'its', 'head', 'impatiently'): 2,
#  ('its', 'head', 'impatiently', 'and'): 2,
#  ('you', 'can', 't', 'think'): 2,
#  ('as', 'if', 'it', 'had'): 2,
#  ('moment', 'that', 'it', 'was'): 2,
#  ('were', 'nowhere', 'to', 'be'): 2,
#  ('alice', 'as', 'she', 'went'): 2,
#  ('said', 'to', 'herself', 'as'): 2,
#  ('said', 'this', 'she', 'came'): 2,
#  ('out', 'of', 'the', 'house'): 2,
#  ('alice', 'said', 'to', 'herself'): 2,
#  ('that', 'stood', 'near', 'the'): 2,
#  ('she', 'went', 'on', 'growing'): 2,
#  ('went', 'on', 'growing', 'and'): 2,
#  ('out', 'of', 'the', 'window'): 2,
#  ('as', 'there', 'seemed', 'to'): 2,
#  ('out', 'of', 'the', 'room'): 2,
#  ('i', 'almost', 'wish', 'i'): 2,
#  ('in', 'the', 'middle', 'of'): 2,
#  ('up', 'to', 'the', 'door'): 2,
#  ('to', 'the', 'door', 'and'): 2,
#  ('in', 'at', 'the', 'window'): 2,
#  ('spread', 'out', 'her', 'hand'): 2,
#  ('snatch', 'in', 'the', 'air'): 2,
#  ('a', 'little', 'shriek', 'and'): 2,
#  ('it', 's', 'an', 'arm'): 2,
#  ('sure', 'i', 'don', 't'): 2,
#  ('i', 'wonder', 'what', 'they'): 2,
#  ('i', 'don', 't', 'want'): 2,
#  ('don', 't', 'want', 'to'): 2,
#  ('for', 'some', 'time', 'without'): 2,
#  ('s', 'to', 'go', 'down'): 2,
#  ('to', 'go', 'down', 'the'): 2,
#  ('go', 'down', 'the', 'chimney'): 2,
#  ('but', 'i', 'think', 'i'): 2,
#  ('as', 'she', 'could', 'and'): 2,
#  ('what', 'would', 'happen', 'next'): 2,
#  ('the', 'rabbit', 's', 'voice'): 2,
#  ('all', 'i', 'know', 'is'): 2,
#  ('there', 'was', 'a', 'dead'): 2,
#  ('was', 'a', 'dead', 'silence'): 2,
#  ('after', 'a', 'minute', 'or'): 2,
#  ('minute', 'or', 'two', 'they'): 2,
#  ('of', 'what', 'thought', 'alice'): 2,
#  ('you', 'd', 'better', 'not'): 2,
#  ('a', 'bright', 'idea', 'came'): 2,
#  ('bright', 'idea', 'came', 'into'): 2,
#  ('and', 'was', 'delighted', 'to'): 2,
#  ('was', 'delighted', 'to', 'find'): 2,
#  ('delighted', 'to', 'find', 'that'): 2,
#  ('as', 'soon', 'as', 'she'): 2,
#  ('of', 'the', 'house', 'and'): 2,
#  ('the', 'moment', 'she', 'appeared'): 2,
#  ('to', 'do', 'said', 'alice'): 2,
#  ('to', 'my', 'right', 'size'): 2,
#  ('the', 'only', 'difficulty', 'was'): 2,
#  ('only', 'difficulty', 'was', 'that'): 2,
#  ('up', 'in', 'a', 'great'): 2,
#  ('at', 'the', 'stick', 'and'): 2,
#  ('the', 'other', 'side', 'the'): 2,
#  ('a', 'good', 'opportunity', 'for'): 2,
#  ('out', 'of', 'breath', 'and'): 2,
#  ('i', 'd', 'nearly', 'forgotten'): 2,
#  ('to', 'eat', 'or', 'drink'): 2,
#  ('alice', 'looked', 'all', 'round'): 2,
#  ('but', 'she', 'did', 'not'): 2,
#  ('sides', 'of', 'it', 'and'): 2,
#  ('the', 'caterpillar', 'took', 'the'): 2,
#  ('caterpillar', 'took', 'the', 'hookah'): 2,
#  ('are', 'you', 'said', 'the'): 2,
#  ('you', 'said', 'the', 'caterpillar'): 2,
#  ('the', 'caterpillar', 'well', 'perhaps'): 2,
#  ('to', 'turn', 'into', 'a'): 2,
#  ('i', 'should', 'think', 'you'): 2,
#  ('a', 'bit', 'said', 'the'): 2,
#  ('alice', 'thought', 'she', 'might'): 2,
#  ('thought', 'she', 'might', 'as'): 2,
#  ('the', 'caterpillar', 'well', 'i'): 2,
#  ('it', 'all', 'came', 'different'): 2,
#  ('in', 'my', 'youth', 'said'): 2,
#  ('how', 'did', 'you', 'manage'): 2,
#  ('for', 'some', 'minutes', 'the'): 2,
#  ('was', 'the', 'first', 'to'): 2,
#  ('you', 'know', 'i', 'don'): 2,
#  ('know', 'i', 'don', 't'): 2,
#  ('alice', 'said', 'nothing', 'she'): 2,
#  ('said', 'nothing', 'she', 'had'): 2,
#  ('and', 'she', 'felt', 'that'): 2,
#  ('wouldn', 't', 'be', 'so'): 2,
#  ('used', 'to', 'it', 'in'): 2,
#  ('in', 'a', 'minute', 'or'): 2,
#  ('side', 'will', 'make', 'you'): 2,
#  ('will', 'make', 'you', 'grow'): 2,
#  ('was', 'a', 'good', 'deal'): 2,
#  ('of', 'the', 'lefthand', 'bit'): 2,
#  ('alice', 'in', 'a', 'tone'): 2,
#  ('to', 'be', 'no', 'chance'): 2,
#  ('be', 'no', 'chance', 'of'): 2,
#  ('m', 'not', 'a', 'serpent'): 2,
#  ('i', 'haven', 't', 'the'): 2,
#  ('and', 'i', 've', 'tried'): 2,
#  ('went', 'on', 'without', 'attending'): 2,
#  ('on', 'without', 'attending', 'to'): 2,
#  ('without', 'attending', 'to', 'her'): 2,
#  ('said', 'the', 'pigeon', 'but'): 2,
#  ('said', 'alice', 'who', 'was'): 2,
#  ('and', 'just', 'as', 'i'): 2,
#  ('said', 'the', 'pigeon', 'in'): 2,
#  ('the', 'pigeon', 'in', 'a'): 2,
#  ('do', 'you', 'know', 'i'): 2,
#  ('a', 'new', 'idea', 'to'): 2,
#  ('new', 'idea', 'to', 'alice'): 2,
#  ('silent', 'for', 'a', 'minute'): 2,
#  ('in', 'a', 'sulky', 'tone'): 2,
#  ('and', 'every', 'now', 'and'): 2,
#  ('set', 'to', 'work', 'very'): 2,
#  ('did', 'not', 'venture', 'to'): 2,
#  ('out', 'of', 'the', 'wood'): 2,
#  ('over', 'to', 'the', 'other'): 2,
#  ('up', 'into', 'the', 'sky'): 2,
#  ('said', 'the', 'footman', 'and'): 2,
#  ('i', 'm', 'on', 'the'): 2,
#  ('can', 't', 'help', 'it'): 2,
#  ('the', 'top', 'of', 'his'): 2,
#  ('i', 'shall', 'sit', 'here'): 2,
#  ('at', 'this', 'moment', 'the'): 2,
#  ('one', 'of', 'the', 'trees'): 2,
#  ('alice', 'did', 'not', 'like'): 2,
#  ('not', 'like', 'to', 'be'): 2,
#  ('what', 'am', 'i', 'to'): 2,
#  ('am', 'i', 'to', 'do'): 2,
#  ('you', 'tell', 'me', 'said'): 2,
#  ('tell', 'me', 'said', 'alice'): 2,
#  ('me', 'said', 'alice', 'a'): 2,
#  ('a', 'cheshire', 'cat', 'said'): 2,
#  ('the', 'duchess', 'and', 'that'): 2,
#  ('duchess', 'and', 'that', 's'): 2,
#  ('she', 'said', 'the', 'last'): 2,
#  ('didn', 't', 'know', 'that'): 2,
#  ('alice', 'said', 'very', 'politely'): 2,
#  ('did', 'not', 'at', 'all'): 2,
#  ('thought', 'it', 'would', 'be'): 2,
#  ('said', 'in', 'a', 'hoarse'): 2,
#  ('listening', 'so', 'she', 'went'): 2,
#  ('said', 'the', 'duchess', 'i'): 2,
#  ('beat', 'him', 'when', 'he'): 2,
#  ('him', 'when', 'he', 'sneezes'): 2,
#  ('and', 'the', 'poor', 'little'): 2,
#  ('play', 'croquet', 'with', 'the'): 2,
#  ('croquet', 'with', 'the', 'queen'): 2,
#  ('poor', 'little', 'thing', 'was'): 2,
#  ('said', 'alice', 'that', 's'): 2,
#  ('there', 'could', 'be', 'no'): 2,
#  ('did', 'not', 'like', 'the'): 2,
#  ('not', 'like', 'the', 'look'): 2,
#  ('the', 'look', 'of', 'the'): 2,
#  ('perhaps', 'it', 'was', 'only'): 2,
#  ('she', 'felt', 'that', 'it'): 2,
#  ('said', 'to', 'herself', 'it'): 2,
#  ('she', 'was', 'a', 'little'): 2,
#  ('was', 'a', 'little', 'startled'): 2,
#  ('it', 'ought', 'to', 'be'): 2,
#  ('added', 'as', 'an', 'explanation'): 2,
#  ('that', 'said', 'the', 'cat'): 2,
#  ('how', 'do', 'you', 'know'): 2,
#  ('it', 'at', 'all', 'however'): 2,
#  ('the', 'cat', 'and', 'vanished'): 2,
#  ('in', 'a', 'natural', 'way'): 2,
#  ('looked', 'up', 'and', 'there'): 2,
#  ('i', 'wish', 'you', 'wouldn'): 2,
#  ('wish', 'you', 'wouldn', 't'): 2,
#  ('i', 've', 'often', 'seen'): 2,
#  ('of', 'the', 'march', 'hare'): 2,
#  ('and', 'the', 'march', 'hare'): 2,
#  ('the', 'march', 'hare', 'and'): 2,
#  ('it', 'wasn', 't', 'very'): 2,
#  ('wasn', 't', 'very', 'civil'): 2,
#  ('t', 'very', 'civil', 'of'): 2,
#  ('very', 'civil', 'of', 'you'): 2,
#  ('civil', 'of', 'you', 'to'): 2,
#  ('said', 'alice', 'it', 's'): 2,
#  ('said', 'the', 'hatter', 'he'): 2,
#  ('thought', 'alice', 'i', 'm'): 2,
#  ('alice', 'i', 'm', 'glad'): 2,
#  ('i', 'm', 'glad', 'they'): 2,
#  ('it', 'said', 'the', 'march'): 2,
#  ('the', 'march', 'hare', 'went'): 2,
#  ('i', 'mean', 'what', 'i'): 2,
#  ('mean', 'what', 'i', 'say'): 2,
#  ('as', 'well', 'say', 'added'): 2,
#  ('well', 'say', 'added', 'the'): 2,
#  ('with', 'you', 'said', 'the'): 2,
#  ('said', 'the', 'hatter', 'and'): 2,
#  ('the', 'hatter', 'was', 'the'): 2,
#  ('day', 'of', 'the', 'month'): 2,
#  ('said', 'turning', 'to', 'alice'): 2,
#  ('the', 'march', 'hare', 'it'): 2,
#  ('march', 'hare', 'it', 'was'): 2,
#  ('it', 'was', 'the', 'best'): 2,
#  ('was', 'the', 'best', 'butter'): 2,
#  ('could', 'think', 'of', 'nothing'): 2,
#  ('mine', 'said', 'the', 'hatter'): 2,
#  ('the', 'march', 'hare', 'alice'): 2,
#  ('said', 'alice', 'of', 'course'): 2,
#  ('i', 'dare', 'say', 'you'): 2,
#  ('it', 'said', 'the', 'hatter'): 2,
#  ('march', 'hare', 'said', 'to'): 2,
#  ('the', 'queen', 'of', 'hearts'): 2,
#  ('said', 'the', 'hatter', 'with'): 2,
#  ('you', 'come', 'to', 'the'): 2,
#  ('the', 'march', 'hare', 'interrupted'): 2,
#  ('treacle', 'said', 'the', 'dormouse'): 2,
#  ('they', 'were', 'said', 'the'): 2,
#  ('were', 'said', 'the', 'dormouse'): 2,
#  ('why', 'did', 'they', 'live'): 2,
#  ('did', 'they', 'live', 'at'): 2,
#  ('they', 'live', 'at', 'the'): 2,
#  ('live', 'at', 'the', 'bottom'): 2,
#  ('replied', 'in', 'an', 'offended'): 2,
#  ('alice', 'did', 'not', 'quite'): 2,
#  ('and', 'bread', 'and', 'butter'): 2,
#  ('bread', 'and', 'butter', 'and'): 2,
#  ('said', 'it', 'was', 'a'): 2,
#  ('they', 'were', 'learning', 'to'): 2,
#  ('were', 'learning', 'to', 'draw'): 2,
#  ('the', 'place', 'of', 'the'): 2,
#  ('as', 'the', 'march', 'hare'): 2,
#  ('that', 'begins', 'with', 'an'): 2,
#  ('begins', 'with', 'an', 'm'): 2,
#  ('by', 'this', 'time', 'and'): 2,
#  ('this', 'time', 'and', 'was'): 2,
#  ('in', 'all', 'my', 'life'): 2,
#  ('that', 's', 'very', 'curious'): 2,
#  ('t', 'help', 'it', 'said'): 2,
#  ('and', 'said', 'that', 's'): 2,
#  ('and', 'the', 'three', 'gardeners'): 2,
#  ('the', 'three', 'gardeners', 'instantly'): 2,
#  ('like', 'the', 'three', 'gardeners'): 2,
#  ('their', 'hands', 'and', 'feet'): 2,
#  ('the', 'king', 'and', 'queen'): 2,
#  ('king', 'and', 'queen', 'of'): 2,
#  ('and', 'queen', 'of', 'hearts'): 2,
#  ('and', 'the', 'queen', 'said'): 2,
#  ('she', 'went', 'on', 'what'): 2,
#  ('a', 'pack', 'of', 'cards'): 2,
#  ('the', 'queen', 'in', 'a'): 2,
#  ('the', 'king', 'the', 'queen'): 2,
#  ('it', 'please', 'your', 'majesty'): 2,
#  ('down', 'on', 'one', 'knee'): 2,
#  ('said', 'alice', 'and', 'she'): 2,
#  ('silent', 'and', 'looked', 'at'): 2,
#  ('and', 'looked', 'at', 'alice'): 2,
#  ('alice', 'come', 'on', 'then'): 2,
#  ('the', 'queen', 'and', 'alice'): 2,
#  ('it', 's', 'a', 'very'): 2,
#  ('the', 'white', 'rabbit', 'who'): 2,
#  ('close', 'to', 'her', 'ear'): 2,
#  ('under', 'sentence', 'of', 'execution'): 2,
#  ('said', 'alice', 'i', 'don'): 2,
#  ('alice', 'i', 'don', 't'): 2,
#  ('gave', 'a', 'little', 'scream'): 2,
#  ('she', 'had', 'got', 'its'): 2,
#  ('she', 'could', 'not', 'help'): 2,
#  ('and', 'shouting', 'off', 'with'): 2,
#  ('shouting', 'off', 'with', 'his'): 2,
#  ('with', 'his', 'head', 'or'): 2,
#  ('his', 'head', 'or', 'off'): 2,
#  ('head', 'or', 'off', 'with'): 2,
#  ('or', 'off', 'with', 'her'): 2,
#  ('what', 'would', 'become', 'of'): 2,
#  ('the', 'cat', 's', 'head'): 2,
#  ('of', 'it', 'at', 'all'): 2,
#  ('the', 'king', 'and', 'don'): 2,
#  ('king', 'and', 'don', 't'): 2,
#  ('the', 'queen', 'who', 'was'): 2,
#  ('go', 'back', 'and', 'see'): 2,
#  ('to', 'the', 'other', 'side'): 2,
#  ('other', 'side', 'of', 'the'): 2,
#  ('but', 'it', 'doesn', 't'): 2,
#  ('the', 'queen', 'said', 'to'): 2,
#  ('and', 'by', 'the', 'time'): 2,
#  ('back', 'to', 'the', 'game'): 2,
#  ('the', 'mock', 'turtle', 's'): 2,
#  ('thing', 'said', 'the', 'duchess'): 2,
#  ('said', 'the', 'duchess', 'as'): 2,
#  ('they', 'walked', 'off', 'together'): 2,
#  ('walked', 'off', 'together', 'alice'): 2,
#  ('so', 'close', 'to', 'her'): 2,
#  ('duchess', 'and', 'the', 'moral'): 2,
#  ('her', 'sharp', 'little', 'chin'): 2,
#  ('she', 'was', 'beginning', 'to'): 2,
#  ('don', 't', 'even', 'know'): 2,
#  ('t', 'even', 'know', 'what'): 2,
#  ('said', 'the', 'queen', 'i'): 2,
#  ('said', 'the', 'queen', 'and'): 2,
#  ('would', 'be', 'quite', 'as'): 2,
#  ('said', 'the', 'gryphon', 'it'): 2,
#  ('you', 'know', 'come', 'on'): 2,
#  ('mock', 'turtle', 'in', 'a'): 2,
#  ('of', 'the', 'mock', 'turtle'): 2,
#  ('went', 'to', 'school', 'in'): 2,
#  ('to', 'school', 'in', 'the'): 2,
#  ('school', 'in', 'the', 'sea'): 2,
#  ('master', 'was', 'an', 'old'): 2,
#  ('and', 'he', 'went', 'on'): 2,
#  ('said', 'i', 'didn', 't'): 2,
#  ('it', 'said', 'the', 'mock'): 2,
#  ('a', 'little', 'before', 'she'): 2,
#  ('the', 'lobster', 'quadrille', 'the'): 2,
#  ('the', 'mock', 'turtle', 'sighed'): 2,
#  ('mock', 'turtle', 'sighed', 'deeply'): 2,
#  ('turtle', 'sighed', 'deeply', 'and'): 2,
#  ('said', 'the', 'gryphon', 'and'): 2,
#  ('cried', 'the', 'mock', 'turtle'): 2,
#  ('the', 'first', 'figure', 'said'): 2,
#  ('first', 'figure', 'said', 'the'): 2,
#  ('figure', 'said', 'the', 'mock'): 2,
#  ('the', 'mock', 'turtle', 'to'): 2,
#  ('come', 'and', 'join', 'the'): 2,
#  ('and', 'join', 'the', 'dance'): 2,
#  ('you', 'will', 'you', 'join'): 2,
#  ('will', 'you', 'join', 'the'): 2,
#  ('won', 't', 'you', 'won'): 2,
#  ('t', 'you', 'won', 't'): 2,
#  ('won', 't', 'you', 'join'): 2,
#  ('t', 'you', 'join', 'the'): 2,
#  ('would', 'not', 'join', 'the'): 2,
#  ('join', 'the', 'dance', 'would'): 2,
#  ('the', 'dance', 'would', 'not'): 2,
#  ('dance', 'would', 'not', 'could'): 2,
#  ('not', 'would', 'not', 'could'): 2,
#  ('you', 've', 'seen', 'them'): 2,
#  ('the', 'mock', 'turtle', 'but'): 2,
#  ('know', 'what', 'they', 're'): 2,
#  ('they', 'have', 'their', 'tails'): 2,
#  ('have', 'their', 'tails', 'in'): 2,
#  ('their', 'tails', 'in', 'their'): 2,
#  ('tails', 'in', 'their', 'mouths'): 2,
#  ('in', 'their', 'mouths', 'and'): 2,
#  ('does', 'the', 'boots', 'and'): 2,
#  ('the', 'boots', 'and', 'shoes'): 2,
#  ('in', 'a', 'deep', 'voice'): 2,
#  ('an', 'offended', 'tone', 'and'): 2,
#  ('tis', 'the', 'voice', 'of'): 2,
#  ('of', 'the', 'lobster', 'quadrille'): 2,
#  ('later', 'editions', 'continued', 'as'): 2,
#  ('editions', 'continued', 'as', 'follows'): 2,
#  ('on', 'with', 'the', 'next'): 2,
#  ('with', 'the', 'next', 'verse'): 2,
#  ('i', 'passed', 'by', 'his'): 2,
#  ('passed', 'by', 'his', 'garden'): 2,
#  ('soup', 'of', 'the', 'evening'): 2,
#  ('of', 'the', 'evening', 'beautiful'): 2,
#  ('the', 'evening', 'beautiful', 'soup'): 2,
#  ('beautiful', 'soup', 'beau', 'ootiful'): 2,
#  ('soup', 'beau', 'ootiful', 'soo'): 2,
#  ('ootiful', 'soo', 'oop', 'beau'): 2,
#  ('soo', 'oop', 'beau', 'ootiful'): 2,
#  ('oop', 'beau', 'ootiful', 'soo'): 2,
#  ('ootiful', 'soo', 'oop', 'soo'): 2,
#  ('soo', 'oop', 'soo', 'oop'): 2,
#  ('oop', 'soo', 'oop', 'of'): 2,
#  ('e', 'evening', 'beautiful', 'beautiful'): 2,
#  ('evening', 'beautiful', 'beautiful', 'soup'): 2,
#  ('pennyworth', 'only', 'of', 'beautiful'): 2,
#  ('only', 'of', 'beautiful', 'soup'): 2,
#  ('cried', 'the', 'gryphon', 'and'): 2,
#  ('and', 'that', 's', 'the'): 2,
#  ('that', 's', 'the', 'jury'): 2,
#  ('before', 'the', 'trial', 's'): 2,
#  ('put', 'on', 'his', 'spectacles'): 2,
#  ('on', 'their', 'slates', 'and'): 2,
#  ('the', 'white', 'rabbit', 'blew'): 2,
#  ('white', 'rabbit', 'blew', 'three'): 2,
#  ('rabbit', 'blew', 'three', 'blasts'): 2,
#  ('blew', 'three', 'blasts', 'on'): 2,
#  ('three', 'blasts', 'on', 'the'): 2,
#  ('blasts', 'on', 'the', 'trumpet'): 2,
#  ('on', 'the', 'trumpet', 'and'): 2,
#  ('verdict', 'the', 'king', 'said'): 2,
#  ('witness', 'said', 'the', 'king'): 2,
#  ('your', 'majesty', 'he', 'began'): 2,
#  ('turning', 'to', 'the', 'jury'): 2,
#  ('staring', 'at', 'the', 'hatter'): 2,
#  ('give', 'your', 'evidence', 'said'): 2,
#  ('your', 'evidence', 'said', 'the'): 2,
#  ('evidence', 'said', 'the', 'king'): 2,
#  ('the', 'bread', 'and', 'butter'): 2,
#  ('one', 'of', 'the', 'officers'): 2,
#  ('a', 'poor', 'man', 'your'): 2,
#  ('poor', 'man', 'your', 'majesty'): 2,
#  ('the', 'twinkling', 'of', 'the'): 2,
#  ('said', 'the', 'hatter', 'i'): 2,
#  ('was', 'immediately', 'suppressed', 'by'): 2,
#  ('immediately', 'suppressed', 'by', 'the'): 2,
#  ('suppressed', 'by', 'the', 'officers'): 2,
#  ('by', 'the', 'officers', 'of'): 2,
#  ('call', 'the', 'next', 'witness'): 2,
#  ('when', 'the', 'white', 'rabbit'): 2,
#  ('the', 'white', 'rabbit', 'read'): 2,
#  ('in', 'the', 'last', 'few'): 2,
#  ('the', 'last', 'few', 'minutes'): 2,
#  ('down', 'on', 'their', 'slates'): 2,
#  ('are', 'said', 'the', 'king'): 2,
#  ('your', 'majesty', 'said', 'the'): 2,
#  ('in', 'it', 'said', 'the'): 2,
#  ('it', 'the', 'jury', 'all'): 2,
#  ('said', 'the', 'king', 'that'): 2,
#  ('said', 'i', 'could', 'not'): 2,
#  ('i', 'could', 'not', 'swim'): 2,
#  ('we', 'know', 'it', 'to'): 2,
#  ('know', 'it', 'to', 'be'): 2,
#  ('it', 'to', 'be', 'true'): 2,
#  ('i', 'gave', 'her', 'one'): 2,
#  ('gave', 'her', 'one', 'they'): 2,
#  ('her', 'one', 'they', 'gave'): 2,
#  ('one', 'they', 'gave', 'him'): 2,
#  ('they', 'gave', 'him', 'two'): 2,
#  ('they', 'all', 'returned', 'from'): 2,
#  ('all', 'returned', 'from', 'him'): 2,
#  ('returned', 'from', 'him', 'to'): 2,
#  ('from', 'him', 'to', 'you'): 2,
#  ('before', 'she', 'had', 'this'): 2,
#  ('she', 'had', 'this', 'fit'): 2,
#  ('said', 'alice', 'she', 'had'): 2,
#  ('alice', 'she', 'had', 'grown'): 2,
#  ('t', 'believe', 'there', 's'): 2,
#  ('believe', 'there', 's', 'an'): 2,
#  ('there', 's', 'an', 'atom'): 2,
#  ('s', 'an', 'atom', 'of'): 2,
#  ('an', 'atom', 'of', 'meaning'): 2,
#  ('atom', 'of', 'meaning', 'in'): 2,
#  ('she', 'could', 'hear', 'the'): 2,
#  ('the', 'shriek', 'of', 'the'): 2,
#  ('shriek', 'of', 'the', 'gryphon'): 2,
#  ('http', 'www', 'gutenberg', 'org'): 2,
#  ('the', 'united', 'states', 'without'): 2,
#  ('general', 'terms', 'of', 'use'): 2,
#  ('distributing', 'project', 'gutenberg', 'tm'): 2,
#  ('to', 'protect', 'the', 'project'): 2,
#  ('protect', 'the', 'project', 'gutenberg'): 2,
#  ('project', 'gutenberg', 'tm', 'concept'): 2,
#  ('project', 'gutenberg', 'is', 'a'): 2,
#  ('gutenberg', 'is', 'a', 'registered'): 2,
#  ('is', 'a', 'registered', 'trademark'): 2,
#  ('if', 'you', 'do', 'not'): 2,
#  ('project', 'gutenberg', 'tm', 'mission'): 2,
#  ('gutenberg', 'tm', 'mission', 'of'): 2,
#  ('tm', 'mission', 'of', 'promoting'): 2,
#  ('the', 'free', 'distribution', 'of'): 2,
#  ('free', 'distribution', 'of', 'electronic'): 2,
#  ('distribution', 'of', 'electronic', 'works'): 2,
#  ('or', 'any', 'other', 'work'): 2,
#  ('any', 'other', 'work', 'associated'): 2,
#  ('associated', 'in', 'any', 'way'): 2,
#  ('in', 'any', 'way', 'with'): 2,
#  ('with', 'the', 'phrase', 'project'): 2,
#  ('terms', 'of', 'the', 'full'): 2,
#  ('of', 'the', 'full', 'project'): 2,
#  ('any', 'part', 'of', 'this'): 2,
#  ('you', 'do', 'not', 'agree'): 2,
#  ('do', 'not', 'agree', 'to'): 2,
#  ('of', 'this', 'agreement', 'you'): 2,
#  ('this', 'agreement', 'you', 'must'): 2,
#  ('return', 'or', 'destroy', 'all'): 2,
#  ('or', 'destroy', 'all', 'copies'): 2,
#  ('destroy', 'all', 'copies', 'of'): 2,
#  ('tm', 'electronic', 'works', 'in'): 2,
#  ('agree', 'to', 'be', 'bound'): 2,
#  ('to', 'be', 'bound', 'by'): 2,
#  ('be', 'bound', 'by', 'the'): 2,
#  ('bound', 'by', 'the', 'terms'): 2,
#  ('by', 'the', 'terms', 'of'): 2,
#  ('forth', 'in', 'paragraph', 'e'): 2,
#  ('the', 'full', 'terms', 'of'): 2,
#  ('with', 'project', 'gutenberg', 'tm'): 2,
#  ('in', 'the', 'public', 'domain'): 2,
#  ('the', 'public', 'domain', 'in'): 2,
#  ('domain', 'in', 'the', 'united'): 2,
#  ('or', 'creating', 'derivative', 'works'): 2,
#  ('creating', 'derivative', 'works', 'based'): 2,
#  ('derivative', 'works', 'based', 'on'): 2,
#  ('all', 'references', 'to', 'project'): 2,
#  ('references', 'to', 'project', 'gutenberg'): 2,
#  ('with', 'the', 'terms', 'of'): 2,
#  ('of', 'this', 'agreement', 'for'): 2,
#  ('to', 'the', 'terms', 'of'): 2,
#  ('immediate', 'access', 'to', 'the'): 2,
#  ('access', 'to', 'the', 'full'): 2,
#  ('of', 'a', 'project', 'gutenberg'): 2,
#  ('which', 'the', 'phrase', 'project'): 2,
#  ('e', 'if', 'an', 'individual'): 2,
#  ('if', 'an', 'individual', 'project'): 2,
#  ('an', 'individual', 'project', 'gutenberg'): 2,
#  ('individual', 'project', 'gutenberg', 'tm'): 2,
#  ('tm', 'electronic', 'work', 'is'): 2,
#  ('or', 'providing', 'access', 'to'): 2,
#  ('paragraphs', 'e', 'through', 'e'): 2,
#  ('e', 'or', 'e', 'e'): 2,
#  ('posted', 'with', 'the', 'permission'): 2,
#  ('with', 'the', 'permission', 'of'): 2,
#  ('the', 'permission', 'of', 'the'): 2,
#  ...}

# %%
def findLastWords(str, count=1):
    if count<= 0:
        return []
    str = str.lower()
    str = str.rstrip()
    #
    lastWordIndex = str.rfind( ' ', 0, len(str))
    lastWord = ''
    if lastWordIndex == -1:
        return [str]
    else:
        rec = findLastWords(str[:lastWordIndex], count-1)
        rec.append( str[(lastWordIndex+1):] )
        return rec

def predict(str):
    choices = []
    for gram in Ngrams:
        choice_i = [ (w,x) for (w,x) in gram.items() if w[:-1] == tuple( str[(len(str)-len(w)+1):] )]
        choices.append( choice_i )
    return choices

def predictMaxLag(list_of_words):
    for gram in Ngrams:
        choice = [ (w,x) for (w,x) in gram.items() if w[:-1] == tuple( list_of_words[(len(list_of_words)-len(w)+1):] )]
        if choice != []:
            return choice
    return []

import random
def weighted_choice(choice):
   total = sum(w for c, w in choice)
   r = random.uniform(0, total)
   upto = 0
   for c, w in choice:
      if upto + w > r:
         return c
      upto += w
    
    
def generate(list_of_words):
    choice = predictMaxLag(list_of_words)
    value = weighted_choice(choice)
    return value[-1]

# %%
strings = findLastWords( "kinf of the jungle and of the wild", count=3)
print( strings )
print("")
choice = predictMaxLag( strings )
print(choice)
gen = generate(strings)
print(gen)
# Out:
# ['of', 'the', 'wild']
#
# [(('wild', 'beasts'), 1), (('wild', 'beast'), 1)]
# beasts

# %%
a = list( Ngrams[0] )
print(a[:50])
# Out:
# [('said', 'the', 'mock', 'turtle'), ('project', 'gutenberg', 'tm', 'electronic'), ('she', 'said', 'to', 'herself'), ('the', 'project', 'gutenberg', 'tm'), ('the', 'project', 'gutenberg', 'literary'), ('project', 'gutenberg', 'literary', 'archive'), ('gutenberg', 'literary', 'archive', 'foundation'), ('gutenberg', 'tm', 'electronic', 'works'), ('a', 'minute', 'or', 'two'), ('you', 'won', 't', 'you'), ('terms', 'of', 'this', 'agreement'), ('said', 'the', 'march', 'hare'), ('will', 'you', 'won', 't'), ('project', 'gutenberg', 'tm', 'license'), ('the', 'terms', 'of', 'this'), ('of', 'project', 'gutenberg', 'tm'), ('of', 'the', 'project', 'gutenberg'), ('said', 'alice', 'in', 'a'), ('i', 'don', 't', 'know'), ('to', 'the', 'project', 'gutenberg'), ('alice', 's', 'adventures', 'in'), ('s', 'adventures', 'in', 'wonderland'), ('as', 'well', 'as', 'she'), ('well', 'as', 'she', 'could'), ('in', 'a', 'great', 'hurry'), ('in', 'a', 'tone', 'of'), ('the', 'moral', 'of', 'that'), ('moral', 'of', 'that', 'is'), ('won', 't', 'you', 'will'), ('t', 'you', 'will', 'you'), ('the', 'full', 'project', 'gutenberg'), ('full', 'project', 'gutenberg', 'tm'), ('gutenberg', 'tm', 'electronic', 'work'), ('out', 'of', 'the', 'way'), ('i', 've', 'got', 'to'), ('the', 'little', 'golden', 'key'), ('the', 'poor', 'little', 'thing'), ('as', 'she', 'said', 'this'), ('she', 'said', 'this', 'she'), ('i', 'beg', 'your', 'pardon'), ('said', 'the', 'duchess', 'and'), ('said', 'the', 'king', 'and'), ('and', 'the', 'moral', 'of'), ('in', 'the', 'united', 'states'), ('a', 'project', 'gutenberg', 'tm'), ('project', 'gutenberg', 'tm', 'works'), ('project', 'gutenberg', 'tm', 'work'), ('the', 'terms', 'of', 'the'), ('as', 'she', 'could', 'for'), ('she', 'did', 'not', 'like')]

# %%
length=24
str = ''
for i in range(1,length):
    end = findLastWords(str, count=3)
    nextWord = generate(end)
    str = str + ' ' + nextWord
    print(str)
# Out:
#  the
#  the other
#  the other as
#  the other as soon
#  the other as soon as
#  the other as soon as she
#  the other as soon as she had
#  the other as soon as she had nothing
#  the other as soon as she had nothing else
#  the other as soon as she had nothing else to
#  the other as soon as she had nothing else to do
#  the other as soon as she had nothing else to do so
#  the other as soon as she had nothing else to do so shall
#  the other as soon as she had nothing else to do so shall we
#  the other as soon as she had nothing else to do so shall we try
#  the other as soon as she had nothing else to do so shall we try another
#  the other as soon as she had nothing else to do so shall we try another figure
#  the other as soon as she had nothing else to do so shall we try another figure of
#  the other as soon as she had nothing else to do so shall we try another figure of the
#  the other as soon as she had nothing else to do so shall we try another figure of the lobster
#  the other as soon as she had nothing else to do so shall we try another figure of the lobster quadrille
#  the other as soon as she had nothing else to do so shall we try another figure of the lobster quadrille the
#  the other as soon as she had nothing else to do so shall we try another figure of the lobster quadrille the mock

# %% [markdown]
# # IV. Conclusion
#
# - Les N-grams sont certainement utiles pour l'autocompletion
# - C'est simple: les chaines de Markov datent de 1913
# - Trop simple: de tels prédicteurs de mots peuvent être utilisés pour la génération de textes, mais peu de robustesse au niveau de la sémantique
