# %%
from numpy import zeros, int8, log
import pylab
import sys
import re
import time
import codecs

# %%
def initializeParameters(n, m, k, lamda, theta):
    for i in range(0, n):
        normalization = sum(lamda[i, :])
        for j in range(0, k):
            lamda[i, j] /= normalization

    for i in range(0, k):
        normalization = sum(theta[i, :])
        for j in range(0, m):
            theta[i, j] /= normalization

# %%
def do_e_step(n, m, k, lamda, theta, p):
    for i in range(0, n):
        for j in range(0, m):
            denominator = 0
            for ik in range(0, k):
                p[i, j, ik] = theta[ik, j] * lamda[i, ik]
                denominator += p[i, j, ik]
            if denominator == 0:
                for ik in range(0, k):
                    p[i, j, ik] = 0
            else:
                for ik in range(0, k):
                    p[i, j, ik] /= denominator

# %%
def do_m_step(n, m, k, lamda, theta, p, docs):
    # update theta
    for ik in range(0, k):
        denominator = 0
        for j in range(0, m):
            theta[ik, j] = 0
            for i in range(0, n):
                theta[ik, j] += docs[i, j] * p[i, j, ik]
            denominator += theta[ik, j]
        if denominator == 0:
            for j in range(0, m):
                theta[ik, j] = 1.0 / m
        else:
            for j in range(0, m):
                theta[ik, j] /= denominator
    # update lamda
    for i in range(0, n):
        for ik in range(0, k):
            lamda[i, ik] = 0
            denominator = 0
            for j in range(0, m):
                lamda[i, ik] += docs[i, j] * p[i, j, ik]
                denominator += docs[i, j]
            if denominator == 0:
                lamda[i, ik] = 1.0 / k
            else:
                lamda[i, ik] /= denominator

# %%
# calculate the log likelihood
def LogLikelihood(n, m, k, lamda, theta, docs):
    loglikelihood = 0
    for i in range(0, n):
        for j in range(0, m):
            tmp = 0
            for ik in range(0, k):
                tmp += theta[ik, j] * lamda[i, ik]
            if tmp > 0:
                loglikelihood += docs[i, j] * log(tmp)
    return loglikelihood

# %%
import gzip
import json
import numpy as np
from collections import defaultdict

workpath="/data/jmoreno/Datasets/signalmedia/"

f=gzip.open(workpath+'signalmedia-1k.jsonl.gz','rb')


docs=[json.loads(s.decode('utf-8')) for s in f.readlines()]
titres=[x['title'] for x in docs]
content=[x['content'] for x in docs]
print(len(titres))

def sentense2cleanTokens(sent):
    sent = sent.lower()
    sent = "".join([x if x.isalpha() else " " for x in sent])
    sent = " ".join(sent.split())
    return sent


cleantitres=[sentense2cleanTokens(x) for x in content]

from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer(min_df=5, stop_words='english')
tfidfsk = tfidf_vectorizer.fit_transform(cleantitres)
# Out:
# 1000

# %%
def PLSA(docs, k, niter=10, threshold=10.0):
    n = len(docs)
    m = docs[0].size
    # lamda[i, j] : p(zj|di)
    lamda = pylab.random([n, n_topics])

    # theta[i, j] : p(wj|zi)
    theta = pylab.random([n_topics, m])

    # p[i, j, k] : p(zk|di,wj)
    p = zeros([n, m, n_topics])
    initializeParameters(n,m,k,lamda,theta)

    # EM algorithm
    oldLoglikelihood = 1
    newLoglikelihood = 1
    for i in range(niter):
        do_e_step(n, m, k, lamda, theta, p)
        do_m_step(n, m, k, lamda, theta, p, docs)
        newLoglikelihood = LogLikelihood(n, m, k, lamda, theta, docs)
        print("Iter=",i+1, "LogLikelihood=", str(newLoglikelihood))
        if(oldLoglikelihood != 1 and newLoglikelihood - oldLoglikelihood < threshold):
            break
        oldLoglikelihood = newLoglikelihood
    return lamda,theta,p

# %%
n_topics=10

lamda,theta,p = PLSA(tfidfsk.todense(),n_topics)
# Out:
# Iter= 1 LogLikelihood= -62265.6522015
# Iter= 2 LogLikelihood= -62044.223311
# Iter= 3 LogLikelihood= -61791.6190231
# Iter= 4 LogLikelihood= -61488.5529111
# Iter= 5 LogLikelihood= -61144.7722196
# Iter= 6 LogLikelihood= -60787.6404451
# Iter= 7 LogLikelihood= -60445.5141423
# Iter= 8 LogLikelihood= -60136.0522363
# Iter= 9 LogLikelihood= -59865.7475652
# Iter= 10 LogLikelihood= -59634.0689689

# %%
ivocab = tfidf_vectorizer.get_feature_names()
clusters=defaultdict(list)
for i, doclamda in enumerate(lamda):
    clusters[np.argmax(doclamda)].append(i)
for i in range(len(theta)):
    print("\n-----\nCluster label:"," ".join([ivocab[x] for x in np.argsort(theta[i])[::-1][:10]]))
    print([titres[x] for x in clusters[i][:10]])
# Out:
# -----
# Cluster label: game said season people year city think court appeared home
# ['2015’s Opening Game Predictions', 'Police chiefs warn ministers Were too broke to go on the beat', 'PINK SLAMS DEMI?!', 'NHS patients to be given option of travelling to Calais for surgical procedures', 'Caterpillar Still On Hook For $4.5M In Wash. Asbestos Suit', "Facebook ready to test button that goes beyond 'like'", "Berra's best World Series unrewarded", 'How Did Trump Do in the Debate?', 'UPDATE 1-German president warns of limits to number of refugees', 'Dancing On Ice skater rapist Joseph Tsang captured in Hong Kong honey trap']
#
# -----
# Cluster label: said india use mr garden year add management government program
# ['Worcester breakfast club for veterans gives hunger its marching orders', 'Hockey mum on multinational tax revenue', 'The Streaming Media Device Landscape', 'Nursery celebrates six years since its opening', 'West Brom turn down another Tottenham bid for Saido Berahino', 'Christmas holiday dollar-saving tips', 'Coach: Serena lost her way mentally and tactically', "Volunteers at Budapest station set up projector showing 'Tom and Jerry' for refugee children", 'AFIF Entrepreneurship Award 2015 Officially Open To All African-Based Entrepreneurs', 'Turkey: Foreign trade deficit narrows sharply in August']
#
# -----
# Cluster label: health com said insurance police september york new group meeting
# ["Five key plays from Texas State's home opener", "Corey Seager's days as the Dodgers' starting shortstop are numbered", "Calcium supplements 'have little effect on bone health'", 'Cops quickly nab 2 men in Jersey City car wash attack', 'Pluto coming out of Retrograde!', 'September Shape Up!', "Mega Buzz: Elementary Returns with Sherlock's Calculating Dad and a Familiar Villain", "Spennymoor Town must be wary of 'full of confidence' Clitheroe, says Jason Ainsley", 'Is Your Nutrition Cutting It?', 'Hurricane Joaquin Moving Closer To East Co...']
#
# -----
# Cluster label: said september story community share week yards department just run
# ['The Return Of The Nike Air Max Sensation Has 80’s Babies Hyped!', 'This New Dating App Will Ruin Your Internet Game', 'THE INFLUENCE OF OUR WORDS', 'New Hillary Clinton email chain discovered', 'Coalition’s Shorten dividend', "It's a Mad world at the Melbourne Bar, as long as you're a man", '“Hybrid” healer for “horrors”', 'Jackson meets with Seattle', 'Student Rocketeers Wanted for World’s Largest Rocket Competition 2015-2016', 'International Industry Sparks Economic Development Opportunities For Washington County']
#
# -----
# Cluster label: new september york report image news city press com information
# ["Hands on with Apple's iPhone 6s, iPad Pro and Apple TV", "The Tom and Jerry Show: 'PM; Watson will run the Labour show while 'President' Corbyn carries on campaigning", 'Cormant Showcases its Array of DCIM Expertise at AFCOMs Fall Data Center World Event in Maryland', "Virgin America Offers Free Uber Rides With Every Dallas Love Field Flight* And Brings 'Friday Night Flights' To The Big D", 'Hilo man, 26, charged with theft of county vehicles, ukulele', 'IPS gaming monitor has great viewing angles', 'Week Four Friday Night Lights', 'Capitals Peters Undergoes ‘Successful’ Knee Surgery', 'New Honda Pilot looks smaller, adds interior space', 'Family Day Trip to a Kid-Friendly Long Island Winery']
#
# -----
# Cluster label: market shares com th second new newswire company pr rating
# ['Harwood Feffer LLP Announces Investigation of VASCO Data Security International, Inc.', "Bayern Munich's Arjen Robben Sidelined With Groin Injury", 'Meredith and Walt Disney are big market movers', "America's Most Expensive Rental Markets", "Can you hear what you're saying?", 'Super Fund, Infratil to sell shares in Z Energy', "Master Stylist of the Hair Connoisseur's Salon, LLC Helps Clients Achieve Self-Image", "JoJo Is Back With a Sexy New Video, Admits Her 2000s Hits 'Take On a New Meaning' Today", 'FIFA’s Sepp Blatter Investigated by Swiss Authorities', 'Leigh Centurions lose out 34-12 in Middle 8s clash with Halifax 34']
#
# -----
# Cluster label: apple life music like dollar need online best public account
# ['Euro up; USD, Pound and Yen down', "Sheriff's department says San...", 'Air Waves - Parting Glances (2015)', 'Lawsuit hovers over AirEvac heliport construction', 'TinderBox Launches TinderBox Signals to Provide Sales Teams, Execs...', 'Deputies testify in trial of Los Alamos standoff suspect', 'Panelists say fewer births, marriages point to global demographic shift', 'Awareness on e-roll & registration', 'PDP celebrates Nigeria’s delisting from Polio endemic countries', '9 excellent parenting hacks']
#
# -----
# Cluster label: percent data com software rates company price market sales fed
# ['Jumpshot Gives Marketers Renewed Visibility Into Paid and Organic Keywords With Launch of Jumpshot Elite', 'Semtech (SMTC) Trading Near $17.29 Resistance Level', 'MY TAKE ON THIS: Politicians should give us a break on empty promises', 'Potts Law Firm Files 90 New GM Ignition Switch Claims in St. Louis', "Iran Parliament Chief: Nuclear Deal Is 'Acceptable,' U.S. Interpretation Is Not", 'New Inflation Estimates Offer First Look at Impact for Taxpayers in 2016', 'Nixing cosmetic repairs could lower property ins.', 'Services Sector Movers: Twenty-First Century Fox, Inc. (FOXA), Las Vegas Sands Corp. (LVS), American Airlines Group Inc. (AAL), DryShips, Inc. (DRYS), Carnival Corporation (CCL)', '3 ways rising interest rates can impact businesses', "Adams says covering Swift's '1989' was 'incredibly humbling'"]
#
# -----
# Cluster label: said business oil state people services good president company ve
# ['Pay up or face legal action: DBKL', "Survivor Upset Use of 'Eye of the Tiger' With Kim Davis", 'Watkins the star in Wormelow awards evening', 'City welcomes Scotland before Rugby World Cup kicks off tomorrow', "Whitemoor prisoner 'kept in solitary for more than two years'", 'Warmongers declare themselves as God over other human beings – Carl Teichrib', 'Video - Jace Hymas 3rd Place - Bob Firman Invitational 2015', 'Garbage thrown at Ahmed’s tour', 'South Street Seaport is getting a seafood-themed food hall', 'Sept. 28, 2015, 10pm (PDT) - ETs and You with Author Elizabeth Anglin']
#
# -----
# Cluster label: school mr students th saturday way com family said team
# ['What will happen to Peta Credlin and Brian Loughnane, Liberal power couple?', 'Former pitcher Andujar dies at 62', 'Thanking Research and Hope honorees for their efforts fighting cancer', 'Weleda Announces Partnership Benefiting Whole Kids Foundation', 'Local Happenings: Danville\'s Village Theatre presenting "Streetcar Named Desire" stage performance, film screening', 'Mailbag: Who Starts At RB? Is The Fifth WR On The Roster Right Now?', 'No. 4 Baylor shows plenty of offense in 56-21 win at SMU', 'September 19, 20', 'THE OPTIMISTIC FISHERMAN', "Palmer's ex-friend seeks 'promised' cash (AAP)"]

# %%
lamda,theta,p = PLSA(tfidfsk.todense(),n_topics, niter=50)

clusters=defaultdict(list)
for i, doclamda in enumerate(lamda):
    clusters[np.argmax(doclamda)].append(i)
for i in range(len(theta)):
    print("\n-----\nCluster label:"," ".join([ivocab[x] for x in np.argsort(theta[i])[::-1][:10]]))
    print([titres[x] for x in clusters[i][:10]])
# Out:
# Iter= 1 LogLikelihood= -62261.3779017
# Iter= 2 LogLikelihood= -62033.8794534
# Iter= 3 LogLikelihood= -61773.7125932
# Iter= 4 LogLikelihood= -61461.573419
# Iter= 5 LogLikelihood= -61108.696449
# Iter= 6 LogLikelihood= -60745.0348994
# Iter= 7 LogLikelihood= -60400.5513823
# Iter= 8 LogLikelihood= -60091.8081019
# Iter= 9 LogLikelihood= -59821.7859213
# Iter= 10 LogLikelihood= -59587.5248803
# Iter= 11 LogLikelihood= -59384.9115852
# Iter= 12 LogLikelihood= -59209.9188246
# Iter= 13 LogLikelihood= -59058.8993532
# Iter= 14 LogLikelihood= -58928.5888498
# Iter= 15 LogLikelihood= -58815.4514743
# Iter= 16 LogLikelihood= -58716.3084387
# Iter= 17 LogLikelihood= -58629.132674
# Iter= 18 LogLikelihood= -58552.0355115
# Iter= 19 LogLikelihood= -58483.1346166
# Iter= 20 LogLikelihood= -58421.3078934
# Iter= 21 LogLikelihood= -58365.6086048
# Iter= 22 LogLikelihood= -58314.5636064
# Iter= 23 LogLikelihood= -58267.5401251
# Iter= 24 LogLikelihood= -58224.260806
# Iter= 25 LogLikelihood= -58184.0378343
# Iter= 26 LogLikelihood= -58146.5246636
# Iter= 27 LogLikelihood= -58111.7372348
# Iter= 28 LogLikelihood= -58079.0979604
# Iter= 29 LogLikelihood= -58047.8075061
# Iter= 30 LogLikelihood= -58017.7930269
# Iter= 31 LogLikelihood= -57989.0539113
# Iter= 32 LogLikelihood= -57961.3024426
# Iter= 33 LogLikelihood= -57935.21666
# Iter= 34 LogLikelihood= -57911.1218974
# Iter= 35 LogLikelihood= -57888.4033811
# Iter= 36 LogLikelihood= -57867.1501635
# Iter= 37 LogLikelihood= -57847.4335997
# Iter= 38 LogLikelihood= -57829.0409024
# Iter= 39 LogLikelihood= -57811.6065016
# Iter= 40 LogLikelihood= -57794.8613111
# Iter= 41 LogLikelihood= -57778.6691004
# Iter= 42 LogLikelihood= -57763.2654091
# Iter= 43 LogLikelihood= -57748.8239927
# Iter= 44 LogLikelihood= -57735.0710289
# Iter= 45 LogLikelihood= -57721.9765667
# Iter= 46 LogLikelihood= -57709.5072472
# Iter= 47 LogLikelihood= -57697.5061483
# Iter= 48 LogLikelihood= -57685.9961268
# Iter= 49 LogLikelihood= -57675.1766514
# Iter= 50 LogLikelihood= -57665.0596022
#
# -----
# Cluster label: said president travel new program chief australia time pilot city
# ['Worcester breakfast club for veterans gives hunger its marching orders', "Virgin America Offers Free Uber Rides With Every Dallas Love Field Flight* And Brings 'Friday Night Flights' To The Big D", 'Mailbag: Who Starts At RB? Is The Fifth WR On The Roster Right Now?', "Spennymoor Town must be wary of 'full of confidence' Clitheroe, says Jason Ainsley", 'Shell says it will cease Alaska Arctic exploration, cites disappointing outcome at well', 'New Honda Pilot looks smaller, adds interior space', 'Hong Kong chief executive is not above the executive, judicial and legislative powers - according to the Basic Law', 'Matteo Darmian: United not apex of career', 'Liverpool round-up: Scouts watching Dani Ceballos ahead of January offer', 'Diggers from down under: 11 new wasp species discovered in Australia']
#
# -----
# Cluster label: school health life food nfl research children cancer care students
# ['Thanking Research and Hope honorees for their efforts fighting cancer', 'NHS patients to be given option of travelling to Calais for surgical procedures', "Calcium supplements 'have little effect on bone health'", 'September 19, 20', 'Week Four Friday Night Lights', 'September Shape Up!', 'Is Your Nutrition Cutting It?', 'Awareness on e-roll & registration', 'Dark Era, Fantasy-MMORPG Enters Closed Beta', "Volunteers at Budapest station set up projector showing 'Tom and Jerry' for refugee children"]
#
# -----
# Cluster label: market percent company shares cent price stock million rating year
# ['Euro up; USD, Pound and Yen down', 'Semtech (SMTC) Trading Near $17.29 Resistance Level', "It's a Mad world at the Melbourne Bar, as long as you're a man", 'Meredith and Walt Disney are big market movers', "America's Most Expensive Rental Markets", 'Super Fund, Infratil to sell shares in Z Energy', 'Services Sector Movers: Twenty-First Century Fox, Inc. (FOXA), Las Vegas Sands Corp. (LVS), American Airlines Group Inc. (AAL), DryShips, Inc. (DRYS), Carnival Corporation (CCL)', 'The Streaming Media Device Landscape', '20-Sep-2015 02:19', 'Dollar weakens in tentative trade ahead of Fed decision']
#
# -----
# Cluster label: com city th garden oil lake county facebook email sep
# ["Survivor Upset Use of 'Eye of the Tiger' With Kim Davis", 'Local Happenings: Danville\'s Village Theatre presenting "Streetcar Named Desire" stage performance, film screening', 'Lawsuit hovers over AirEvac heliport construction', 'City welcomes Scotland before Rugby World Cup kicks off tomorrow', 'Jackson meets with Seattle', 'Nixing cosmetic repairs could lower property ins.', "Master Stylist of the Hair Connoisseur's Salon, LLC Helps Clients Achieve Self-Image", 'THE OPTIMISTIC FISHERMAN', 'South Street Seaport is getting a seafood-themed food hall', 'Nursery celebrates six years since its opening']
#
# -----
# Cluster label: apple like just new music make don time little ll
# ['The Return Of The Nike Air Max Sensation Has 80’s Babies Hyped!', 'This New Dating App Will Ruin Your Internet Game', 'THE INFLUENCE OF OUR WORDS', "Hands on with Apple's iPhone 6s, iPad Pro and Apple TV", "Facebook ready to test button that goes beyond 'like'", 'IPS gaming monitor has great viewing angles', 'Pluto coming out of Retrograde!', "Mega Buzz: Elementary Returns with Sherlock's Calculating Dad and a Familiar Villain", 'Panelists say fewer births, marriages point to global demographic shift', 'Family Day Trip to a Kid-Friendly Long Island Winery']
#
# -----
# Cluster label: com http www tax company prnewswire data newswire pr business
# ['Jumpshot Gives Marketers Renewed Visibility Into Paid and Organic Keywords With Launch of Jumpshot Elite', 'Harwood Feffer LLP Announces Investigation of VASCO Data Security International, Inc.', 'Weleda Announces Partnership Benefiting Whole Kids Foundation', 'Cormant Showcases its Array of DCIM Expertise at AFCOMs Fall Data Center World Event in Maryland', 'New Inflation Estimates Offer First Look at Impact for Taxpayers in 2016', 'TinderBox Launches TinderBox Signals to Provide Sales Teams, Execs...', 'Hockey mum on multinational tax revenue', 'International Industry Sparks Economic Development Opportunities For Washington County', 'Sept. 28, 2015, 10pm (PDT) - ETs and You with Author Elizabeth Anglin', 'Hardison & Cochran Teams Up with Tar Heels Football to Focus on Autism']
#
# -----
# Cluster label: said just like september going race don cars year time
# ['Police chiefs warn ministers Were too broke to go on the beat', 'PINK SLAMS DEMI?!', 'Air Waves - Parting Glances (2015)', "Can you hear what you're saying?", 'Dark and full-bodied does it for me every time', 'Video - Jace Hymas 3rd Place - Bob Firman Invitational 2015', 'Emmerdale: Natalie Anderson exit interview - Alicia cannot stay in the village', 'PDP celebrates Nigeria’s delisting from Polio endemic countries', "'Game Of Thrones' Creators 'Never Set Out To Offend Anyone'", 'Martín Cáceres suspended by Juventus for alleged drink-driving incident']
#
# -----
# Cluster label: game season games team win play second said league played
# ['Pay up or face legal action: DBKL', '2015’s Opening Game Predictions', 'Former pitcher Andujar dies at 62', "Five key plays from Texas State's home opener", 'MY TAKE ON THIS: Politicians should give us a break on empty promises', "The Tom and Jerry Show: 'PM; Watson will run the Labour show while 'President' Corbyn carries on campaigning", "Bayern Munich's Arjen Robben Sidelined With Groin Injury", "Corey Seager's days as the Dodgers' starting shortstop are numbered", 'Caterpillar Still On Hook For $4.5M In Wash. Asbestos Suit', 'Watkins the star in Wormelow awards evening']
#
# -----
# Cluster label: com google university treatment september clinical boston study data group
# ['Student Rocketeers Wanted for World’s Largest Rocket Competition 2015-2016', 'How Did Trump Do in the Debate?', "Moody's Confirms CM BANK (03968.HK) Long-Term Deposit Rating as Baa1", 'Criminal probe: Volkswagen slams into huge false emission scam', 'Tanmiyat Global launches twin tower development in Dubailand', 'College Choice Releases 2016 Ranking of Northern Regional Universities: Unique College Rankings are Based Exclusively on Factors Entering Freshmen Said Most Important to College Decision', 'Electronic Notebook (ELN)', 'Roxas nasa Naga para ‘ligawan’ si Robredo', 'BioLineRx to Present at the 17th Annual Rodman & Renshaw Global Investment Conference in New York', '256 The Uplands, Berkeley']
#
# -----
# Cluster label: said police government mr minister court people law state president
# ['What will happen to Peta Credlin and Brian Loughnane, Liberal power couple?', 'New Hillary Clinton email chain discovered', "Sheriff's department says San...", 'Potts Law Firm Files 90 New GM Ignition Switch Claims in St. Louis', 'Coalition’s Shorten dividend', "Iran Parliament Chief: Nuclear Deal Is 'Acceptable,' U.S. Interpretation Is Not", 'Hilo man, 26, charged with theft of county vehicles, ukulele', '“Hybrid” healer for “horrors”', 'Cops quickly nab 2 men in Jersey City car wash attack', "Whitemoor prisoner 'kept in solitary for more than two years'"]

# %%
from scipy.special import gammaln, psi

def dirichlet_expectation(alpha):
    """
    For a vector theta ~ Dir(alpha), computes E[log(theta)] given alpha.
    """
    if (len(alpha.shape) == 1):
        return(psi(alpha) - psi(np.sum(alpha)))
    return(psi(alpha) - psi(np.sum(alpha, 1))[:, np.newaxis])

class OnlineLDA:
    """
    Implements online VB for LDA as described in (Hoffman et al. 2010).
    """

    def __init__(self, vocab, K, D, alpha, eta, tau0=1024.0, kappa=0.7):
        """
        Arguments:
        K: Number of topics
        vocab: A set of words to recognize. When analyzing documents, any word
           not in this set will be ignored.
        D: Total number of documents in the population. For a fixed corpus,
           this is the size of the corpus. In the truly online setting, this
           can be an estimate of the maximum number of documents that
           could ever be seen.
        alpha: Hyperparameter for prior on weight vectors theta
        eta: Hyperparameter for prior on topics beta
        tau0: A (positive) learning parameter that downweights early iterations
        kappa: Learning rate: exponential decay rate---should be between
             (0.5, 1.0] to guarantee asymptotic convergence.

        Note that if you pass the same set of D documents in every time and
        set kappa=0 this class can also be used to do batch VB.
        """
        self._vocab = dict()
        for word in vocab:
            self._vocab[word] = len(self._vocab)

        self._K = K
        self._W = len(self._vocab)
        self._D = D
        self._alpha = alpha
        self._eta = eta
        self._tau0 = tau0 + 1
        self._kappa = kappa
        self._updatect = 0

        # Initialize the variational distribution q(beta|lambda)
        self._lambda = 1*np.random.gamma(100., 1./100., (self._K, self._W))
        self._Elogbeta = dirichlet_expectation(self._lambda)
        self._expElogbeta = np.exp(self._Elogbeta)

    def do_e_step(self, wordids, wordcts):
        meanchangethresh = 0.001
        batchD = len(wordids)

        # Initialize the variational distribution q(theta|gamma) for
        # the mini-batch
        gamma = 1*np.random.gamma(100., 1./100., (batchD, self._K))
        Elogtheta = dirichlet_expectation(gamma)
        expElogtheta = np.exp(Elogtheta)

        sstats = np.zeros(self._lambda.shape)
        # Now, for each document d update that document's gamma and phi
        it = 0
        meanchange = 0
        for d in range(0, batchD):
            # print(sum(wordcts[d]))
            # These are mostly just shorthand (but might help cache locality)
            ids = wordids[d]
            cts = wordcts[d]
            gammad = gamma[d, :]
            Elogthetad = Elogtheta[d, :]
            expElogthetad = expElogtheta[d, :]
            expElogbetad = self._expElogbeta[:, ids]
            # The optimal phi_{dwk} is proportional to 
            # expElogthetad_k * expElogbetad_w. phinorm is the normalizer.
            phinorm = np.dot(expElogthetad, expElogbetad) + 1e-100
            # Iterate between gamma and phi until convergence
            for it in range(0, 100):
                lastgamma = gammad
                # We represent phi implicitly to save memory and time.
                # Substituting the value of the optimal phi back into
                # the update for gamma gives this update. Cf. Lee&Seung 2001.
                gammad = self._alpha + expElogthetad * \
                    np.dot(cts / phinorm, expElogbetad.T)
                # print(gammad[:, np.newaxis])
                Elogthetad = dirichlet_expectation(gammad)
                expElogthetad = np.exp(Elogthetad)
                phinorm = np.dot(expElogthetad, expElogbetad) + 1e-100
                # If gamma hasn't changed much, we're done.
                meanchange = np.mean(abs(gammad - lastgamma))
                if (meanchange < meanchangethresh):
                    break
            gamma[d, :] = gammad
            # Contribution of document d to the expected sufficient
            # statistics for the M step.
            sstats[:, ids] += np.outer(expElogthetad.T, cts/phinorm)

        # This step finishes computing the sufficient statistics for the
        # M step, so that
        # sstats[k, w] = \sum_d n_{dw} * phi_{dwk} 
        # = \sum_d n_{dw} * exp{Elogtheta_{dk} + Elogbeta_{kw}} / phinorm_{dw}.
        sstats = sstats * self._expElogbeta

        return((gamma, sstats))

    def update_lambda(self, wordids, wordcts):
        """
        First does an E step on the mini-batch given in wordids and
        wordcts, then uses the result of that E step to update the
        variational parameter matrix lambda.

        Arguments:
        docs:  List of D documents. Each document must be represented
               as a string. (Word order is unimportant.) Any
               words not in the vocabulary will be ignored.

        Returns gamma, the parameters to the variational distribution
        over the topic weights theta for the documents analyzed in this
        update.

        Also returns an estimate of the variational bound for the
        entire corpus for the OLD setting of lambda based on the
        documents passed in. This can be used as a (possibly very
        noisy) estimate of held-out likelihood.
        """

        # rhot will be between 0 and 1, and says how much to weight
        # the information we got from this mini-batch.
        rhot = pow(self._tau0 + self._updatect, -self._kappa)
        self._rhot = rhot
        # Do an E step to update gamma, phi | lambda for this
        # mini-batch. This also returns the information about phi that
        # we need to update lambda.
        (gamma, sstats) = self.do_e_step(wordids, wordcts)
        # Estimate held-out likelihood for current values of lambda.
        bound = self.approx_bound(wordids, wordcts, gamma)
        # Update lambda based on documents.
        self._lambda = self._lambda * (1-rhot) + \
            rhot * (self._eta + self._D * sstats / len(wordids))
        self._Elogbeta = dirichlet_expectation(self._lambda)
        self._expElogbeta = np.exp(self._Elogbeta)
        self._updatect += 1

        return gamma,self._lambda,bound

    def approx_bound(self, wordids, wordcts, gamma):
        """
        Estimates the variational bound over *all documents* using only
        the documents passed in as "docs." gamma is the set of parameters
        to the variational distribution q(theta) corresponding to the
        set of documents passed in.

        The output of this function is going to be noisy, but can be
        useful for assessing convergence.
        """

        # This is to handle the case where someone just hands us a single
        # document, not in a list.
        batchD = len(wordids)

        score = 0
        Elogtheta = dirichlet_expectation(gamma)
        expElogtheta = np.exp(Elogtheta)

        # E[log p(docs | theta, beta)]
        for d in range(0, batchD):
            gammad = gamma[d, :]
            ids = wordids[d]
            cts = np.array(wordcts[d])
            phinorm = np.zeros(len(ids))
            for i in range(0, len(ids)):
                temp = Elogtheta[d, :] + self._Elogbeta[:, ids[i]]
                tmax = max(temp)
                phinorm[i] = np.log(sum(np.exp(temp - tmax))) + tmax
            score += np.sum(cts * phinorm)

        # E[log p(theta | alpha) - log q(theta | gamma)]
        score += np.sum((self._alpha - gamma)*Elogtheta)
        score += np.sum(gammaln(gamma) - gammaln(self._alpha))
        score += sum(gammaln(self._alpha*self._K) - gammaln(np.sum(gamma, 1)))

        # Compensate for the subsampling of the population of documents
        score = score * self._D / len(wordids)

        # E[log p(beta | eta) - log q (beta | lambda)]
        score = score + np.sum((self._eta-self._lambda)*self._Elogbeta)
        score = score + np.sum(gammaln(self._lambda) - gammaln(self._eta))
        score = score + np.sum(gammaln(self._eta*self._W) - 
                              gammaln(np.sum(self._lambda, 1)))

        return(score)

# %%
from sklearn.feature_extraction.text import CountVectorizer
tf_vectorizer = CountVectorizer(min_df=5, stop_words='english')
tfsk = tf_vectorizer.fit_transform(cleantitres)
ivocabtf = tf_vectorizer.get_feature_names()

# %%
ndocs = len(tfsk.todense())
n_topics = 10
olda = OnlineLDA(ivocabtf, n_topics, ndocs, 1./n_topics, 1./n_topics)
tfindices = [list(x.indices) for x in tfsk]
tfdata = [list(x.data) for x in tfsk]

# %%
gamma,_lambda,bound = olda.update_lambda(tfindices,tfdata)
print(bound)
# Out:
# -1661607.7314

# %%
clusters=defaultdict(list)
for i, docgamma in enumerate(gamma):
    clusters[np.argmax(docgamma)].append(i)
for i in range(len(_lambda)):
    print("\n-----\nCluster label:"," ".join([ivocabtf[x] for x in np.argsort(_lambda[i])[::-1][:10]]))
    print([titres[x] for x in clusters[i][:10]])
# Out:
# -----
# Cluster label: said com city jewish th time place technology business event
# ['Worcester breakfast club for veterans gives hunger its marching orders', 'Pay up or face legal action: DBKL', 'Meredith and Walt Disney are big market movers', "America's Most Expensive Rental Markets", 'Local Happenings: Danville\'s Village Theatre presenting "Streetcar Named Desire" stage performance, film screening', "Virgin America Offers Free Uber Rides With Every Dallas Love Field Flight* And Brings 'Friday Night Flights' To The Big D", 'Student Rocketeers Wanted for World’s Largest Rocket Competition 2015-2016', '20-Sep-2015 02:19', 'Shell says it will cease Alaska Arctic exploration, cites disappointing outcome at well', 'Martín Cáceres suspended by Juventus for alleged drink-driving incident']
#
# -----
# Cluster label: said new year people com september like national www way
# ['This New Dating App Will Ruin Your Internet Game', 'Harwood Feffer LLP Announces Investigation of VASCO Data Security International, Inc.', "Sheriff's department says San...", "It's a Mad world at the Melbourne Bar, as long as you're a man", "Corey Seager's days as the Dodgers' starting shortstop are numbered", 'Watkins the star in Wormelow awards evening', 'City welcomes Scotland before Rugby World Cup kicks off tomorrow', "Berra's best World Series unrewarded", 'International Industry Sparks Economic Development Opportunities For Washington County', 'Garbage thrown at Ahmed’s tour']
#
# -----
# Cluster label: saturday team new university game said september caption second time
# ['The Return Of The Nike Air Max Sensation Has 80’s Babies Hyped!', "Five key plays from Texas State's home opener", 'September 19, 20', 'The Streaming Media Device Landscape', 'Capitals Peters Undergoes ‘Successful’ Knee Surgery', 'Awareness on e-roll & registration', 'Nursery celebrates six years since its opening', 'Victor Cruz expected to play in Week 4', 'Criminal probe: Volkswagen slams into huge false emission scam', 'Inmate dies in Tulsa County cell']
#
# -----
# Cluster label: new said company season game state year little know just
# ['Jumpshot Gives Marketers Renewed Visibility Into Paid and Organic Keywords With Launch of Jumpshot Elite', '2015’s Opening Game Predictions', "Bayern Munich's Arjen Robben Sidelined With Groin Injury", 'Potts Law Firm Files 90 New GM Ignition Switch Claims in St. Louis', 'Weleda Announces Partnership Benefiting Whole Kids Foundation', 'NHS patients to be given option of travelling to Calais for surgical procedures', 'Cormant Showcases its Array of DCIM Expertise at AFCOMs Fall Data Center World Event in Maryland', 'Caterpillar Still On Hook For $4.5M In Wash. Asbestos Suit', "Facebook ready to test button that goes beyond 'like'", '“Hybrid” healer for “horrors”']
#
# -----
# Cluster label: said tax new world time president com year south american
# ['Euro up; USD, Pound and Yen down', 'Coalition’s Shorten dividend', 'New Inflation Estimates Offer First Look at Impact for Taxpayers in 2016', 'Cops quickly nab 2 men in Jersey City car wash attack', 'THE OPTIMISTIC FISHERMAN', 'New Honda Pilot looks smaller, adds interior space', 'Is Your Nutrition Cutting It?', 'Hardison & Cochran Teams Up with Tar Heels Football to Focus on Autism', 'Esp Ltd B 208 Fm Bass Guitar See Thru Black Basswood Fm 8 String Lb208fmstblk', 'Letter: Contact PUC re: Dakota Access Pipeline']
#
# -----
# Cluster label: said time game new day apple better group team com
# ['THE INFLUENCE OF OUR WORDS', "Hands on with Apple's iPhone 6s, iPad Pro and Apple TV", 'Semtech (SMTC) Trading Near $17.29 Resistance Level', 'Former pitcher Andujar dies at 62', 'MY TAKE ON THIS: Politicians should give us a break on empty promises', "The Tom and Jerry Show: 'PM; Watson will run the Labour show while 'President' Corbyn carries on campaigning", "Calcium supplements 'have little effect on bone health'", 'Mailbag: Who Starts At RB? Is The Fifth WR On The Roster Right Now?', 'IPS gaming monitor has great viewing angles', 'TALKING TACTICS: finding the right Plan B']
#
# -----
# Cluster label: said people million com government don industry help year cent
# ['Hockey mum on multinational tax revenue', 'UPDATE 1-German president warns of limits to number of refugees', 'Dancing On Ice skater rapist Joseph Tsang captured in Hong Kong honey trap', 'Dark and full-bodied does it for me every time', 'Panelists say fewer births, marriages point to global demographic shift', "Palmer's ex-friend seeks 'promised' cash (AAP)", "JoJo Is Back With a Sexy New Video, Admits Her 2000s Hits 'Take On a New Meaning' Today", '3 ways rising interest rates can impact businesses', 'Record sales for Poundworld', 'A video game fan brings ‘Star Wars’ to your smartphone']
#
# -----
# Cluster label: new just said year news company end research com market
# ['PINK SLAMS DEMI?!', 'Air Waves - Parting Glances (2015)', "Can you hear what you're saying?", 'Lawsuit hovers over AirEvac heliport construction', 'Deputies testify in trial of Los Alamos standoff suspect', 'Nixing cosmetic repairs could lower property ins.', "Master Stylist of the Hair Connoisseur's Salon, LLC Helps Clients Achieve Self-Image", 'Emmerdale: Natalie Anderson exit interview - Alicia cannot stay in the village', 'PDP celebrates Nigeria’s delisting from Polio endemic countries', 'Dark Era, Fantasy-MMORPG Enters Closed Beta']
#
# -----
# Cluster label: year court new frankfurt continue kevin biggest hotel day management
# ['What will happen to Peta Credlin and Brian Loughnane, Liberal power couple?', 'New Hillary Clinton email chain discovered', 'Police chiefs warn ministers Were too broke to go on the beat', 'Thanking Research and Hope honorees for their efforts fighting cancer', "Survivor Upset Use of 'Eye of the Tiger' With Kim Davis", 'Hilo man, 26, charged with theft of county vehicles, ukulele', 'TinderBox Launches TinderBox Signals to Provide Sales Teams, Execs...', "Whitemoor prisoner 'kept in solitary for more than two years'", 'Jackson meets with Seattle', 'Warmongers declare themselves as God over other human beings – Carl Teichrib']
#
# -----
# Cluster label: said million energy just time new state second percent year
# ["Iran Parliament Chief: Nuclear Deal Is 'Acceptable,' U.S. Interpretation Is Not", 'Super Fund, Infratil to sell shares in Z Energy', 'Family Day Trip to a Kid-Friendly Long Island Winery', "With This Answer, Anthony Anderson's Mom Proves You're Never Too Old To Be Embarrassed By Your Parents", 'Nasarawa gets N8bn bailout, plans to employ 1500 workers', 'FIFA’s Sepp Blatter Investigated by Swiss Authorities', 'West Brom turn down another Tottenham bid for Saido Berahino', 'Hurricane Joaquin Moving Closer To East Co...', 'Wall Street higher ahead of key U.S. jobs data', 'Arsenal and Tottenham to go head to head.']

# %%
import scipy.sparse as sp
from sys import float_info


class NMF(object):
    def __init__(self, A, k=5):
        n, m = A.shape
        W0 = np.random.rand(n, k)
        H0 = np.random.rand(k, m)

        self._errors = []
        self._A = A
        self._H = H0
        self._W = W0
        
    def setWH(self, W, H):
        self._W = W
        self._H = H


    def run(self, niter=100, calc_error_num=10):
        H = self._H
        W = self._W
        eps = float_info.min
        A = self._A
        for i in range(niter):

            # update H
            # H=H.*(W'*A)./(W'*W*H+eps)
            H = H * ((A.T * W).T) / (W.T.dot(W).dot(H) + eps)
            # update W
            # W=W.*(A*H')./(W*(H*H')+eps);
            W = W * (A * H.T) / (W.dot(H.dot(H.T)) + eps)
            if (i+1)%calc_error_num==0:
                M = A - W.dot(H)
                error = np.multiply(M, M).sum()
                self._errors.append(error)
                print("Iter=",i+1, "Error=", str(error))
        self._H = H
        self._W = W
        return W,H

# %%
mynmf = NMF(tfidfsk, n_topics)
W,H = mynmf.run()
# Out:
# Iter= 10 Error= 944.393064172
# Iter= 20 Error= 935.621659477
# Iter= 30 Error= 933.285336116
# Iter= 40 Error= 932.121833161
# Iter= 50 Error= 931.670368424
# Iter= 60 Error= 931.4912954
# Iter= 70 Error= 931.39852162
# Iter= 80 Error= 931.336801744
# Iter= 90 Error= 931.293238229
# Iter= 100 Error= 931.26190672

# %%
def nndsvd(A, n_topics, min_val=0.01):
    U, s, V = np.linalg.svd(A.todense(), full_matrices=True)
    print(U.shape, s.shape, V.shape)
    n, m = A.shape
    W = np.random.rand(n, n_topics)
    H = np.random.rand(n_topics, m)
    #choose the first singular triplet to be nonnegative
    W[:,0] = np.sqrt(s[1]) * abs(np.ravel(U[:,1]))
    H[0,:] = np.sqrt(s[1]) * abs(V[:,1].T)

    #2nd SVD for the other factors
    for i in range(1,n_topics):
        uu = np.ravel(U[:,i])
        vv = np.ravel(V[:,i])
        uup = uu.clip(min=0)
        uun = abs(uu.clip(max=0))
        vvp = vv.clip(min=0)
        vvn = abs(vv.clip(max=0))
        n_uup = np.linalg.norm(uup)
        n_vvp = np.linalg.norm(vvp)
        n_uun = np.linalg.norm(uun)
        n_vvn = np.linalg.norm(vvn)
        termp = n_uup*n_vvp
        termn = n_uun*n_vvn
        if termp >= termn:
            W[:,i] = np.sqrt(s[i]*termp)*uup/n_uup
            H[i,:] = np.sqrt(s[i]*termp)*vvp.T/n_vvp
        else:
            W[:,i] = np.sqrt(s[i]*termn)*uun/n_uun
            H[i,:] = np.sqrt(s[i]*termn)*vvn.T/n_vvn
    W[W==0]=min_val
    H[H==0]=min_val
    return W,H

# %%
W0,H0 = nndsvd(tfidfsk,10)
# Out:
# (1000, 1000) (1000,) (5739, 5739)

# %%
W0
# Out:
# array([[ 0.03833935,  0.01      ,  0.04154105, ...,  0.01      ,
#          0.00535324,  0.00231954],
#        [ 0.11288261,  0.12679343,  0.01      , ...,  0.07377825,
#          0.01      ,  0.01113601],
#        [ 0.02493787,  0.01      ,  0.01      , ...,  0.01      ,
#          0.01162546,  0.0222418 ],
#        ...,
#        [ 0.02226615,  0.02501006,  0.01      , ...,  0.01      ,
#          0.04444898,  0.01      ],
#        [ 0.07489758,  0.08412741,  0.01      , ...,  0.01      ,
#          0.0809301 ,  0.01      ],
#        [ 0.06502651,  0.01      ,  0.01      , ...,  0.0223106 ,
#          0.00992611,  0.01      ]])

# %%
mynmf.setWH(W0,H0)
Wplus,Hplus = mynmf.run()
# Out:
# Iter= 10 Error= 934.425135364
# Iter= 20 Error= 932.193831452
# Iter= 30 Error= 931.541903653
# Iter= 40 Error= 931.30711191
# Iter= 50 Error= 931.196957901
# Iter= 60 Error= 931.137488254
# Iter= 70 Error= 931.099977679
# Iter= 80 Error= 931.073128382
# Iter= 90 Error= 931.050360681
# Iter= 100 Error= 931.033087171

# %%
clusters=defaultdict(list)
for i, docw in enumerate(Wplus):
    clusters[np.argmax(docw)].append(i)
for i in range(len(Hplus)):
    print("\n-----\nCluster label:"," ".join([ivocab[x] for x in np.argsort(Hplus[i])[::-1][:10]]))
    print([titres[x] for x in clusters[i][:10]])
# Out:
# -----
# Cluster label: season team game year league games cup said win rugby
# ['Worcester breakfast club for veterans gives hunger its marching orders', 'The Return Of The Nike Air Max Sensation Has 80’s Babies Hyped!', 'Former pitcher Andujar dies at 62', "Bayern Munich's Arjen Robben Sidelined With Groin Injury", "Corey Seager's days as the Dodgers' starting shortstop are numbered", 'Watkins the star in Wormelow awards evening', 'City welcomes Scotland before Rugby World Cup kicks off tomorrow', "Berra's best World Series unrewarded", 'TALKING TACTICS: finding the right Plan B', "Spennymoor Town must be wary of 'full of confidence' Clitheroe, says Jason Ainsley"]
#
# -----
# Cluster label: company business data market information services solutions technology research products
# ['Jumpshot Gives Marketers Renewed Visibility Into Paid and Organic Keywords With Launch of Jumpshot Elite', 'Semtech (SMTC) Trading Near $17.29 Resistance Level', "It's a Mad world at the Melbourne Bar, as long as you're a man", 'NHS patients to be given option of travelling to Calais for surgical procedures', 'Cormant Showcases its Array of DCIM Expertise at AFCOMs Fall Data Center World Event in Maryland', 'Caterpillar Still On Hook For $4.5M In Wash. Asbestos Suit', 'Lawsuit hovers over AirEvac heliport construction', "Calcium supplements 'have little effect on bone health'", 'TinderBox Launches TinderBox Signals to Provide Sales Teams, Execs...', 'Student Rocketeers Wanted for World’s Largest Rocket Competition 2015-2016']
#
# -----
# Cluster label: police said officers county man sheriff car area old near
# ["Sheriff's department says San...", "Survivor Upset Use of 'Eye of the Tiger' With Kim Davis", 'Hilo man, 26, charged with theft of county vehicles, ukulele', 'Cops quickly nab 2 men in Jersey City car wash attack', 'Deputies testify in trial of Los Alamos standoff suspect', 'International Industry Sparks Economic Development Opportunities For Washington County', 'Dancing On Ice skater rapist Joseph Tsang captured in Hong Kong honey trap', 'FIFA’s Sepp Blatter Investigated by Swiss Authorities', 'Inmate dies in Tulsa County cell', 'Texas teen fatally shoots himself while taking selfie (Reuters)']
#
# -----
# Cluster label: percent shares rating price stock company market dividend august rates
# ['Euro up; USD, Pound and Yen down', 'Meredith and Walt Disney are big market movers', "America's Most Expensive Rental Markets", 'Super Fund, Infratil to sell shares in Z Energy', 'Services Sector Movers: Twenty-First Century Fox, Inc. (FOXA), Las Vegas Sands Corp. (LVS), American Airlines Group Inc. (AAL), DryShips, Inc. (DRYS), Carnival Corporation (CCL)', 'Dollar weakens in tentative trade ahead of Fed decision', '3 ways rising interest rates can impact businesses', 'Christmas holiday dollar-saving tips', 'Turkey: Foreign trade deficit narrows sharply in August', 'Wall Street higher ahead of key U.S. jobs data']
#
# -----
# Cluster label: game yards state touchdown nfl ball yard season michigan week
# ['2015’s Opening Game Predictions', "Five key plays from Texas State's home opener", 'Jackson meets with Seattle', 'No. 4 Baylor shows plenty of offense in 56-21 win at SMU', 'Hardison & Cochran Teams Up with Tar Heels Football to Focus on Autism', 'Victor Cruz expected to play in Week 4', "Can't make it to the tailgate? Host the ultimate 'staygate' instead", '11A powers clash in Madison', 'Eastern falls in first-ever match', 'CFB Week 2 Finals: Notre Dame/UVA Down, But Trounces Competition']
#
# -----
# Cluster label: said government mr president minister state people tax refugees nuclear
# ['Pay up or face legal action: DBKL', 'What will happen to Peta Credlin and Brian Loughnane, Liberal power couple?', 'New Hillary Clinton email chain discovered', 'Coalition’s Shorten dividend', "Iran Parliament Chief: Nuclear Deal Is 'Acceptable,' U.S. Interpretation Is Not", 'New Inflation Estimates Offer First Look at Impact for Taxpayers in 2016', 'Hockey mum on multinational tax revenue', '“Hybrid” healer for “horrors”', "Whitemoor prisoner 'kept in solitary for more than two years'", 'How Did Trump Do in the Debate?']
#
# -----
# Cluster label: apple music iphone ipad new car app watch screen mobile
# ["Hands on with Apple's iPhone 6s, iPad Pro and Apple TV", 'IPS gaming monitor has great viewing angles', 'New Honda Pilot looks smaller, adds interior space', 'Family Day Trip to a Kid-Friendly Long Island Winery', 'Now Lumia 950 & Lumia 950 XL leak from official MS Store in UK', 'Cooking with N.C. apples', 'Madison Dulcimers Club', '3 easy steps to upgrade your computer to the latest operating system', 'Apple sells record 13 mn iPhones in weekend launch', 'Baidu take on Siri and Google Now with Duer AI assistant']
#
# -----
# Cluster label: like just don people make time life love really going
# ['This New Dating App Will Ruin Your Internet Game', 'THE INFLUENCE OF OUR WORDS', 'MY TAKE ON THIS: Politicians should give us a break on empty promises', 'Air Waves - Parting Glances (2015)', "Can you hear what you're saying?", "Facebook ready to test button that goes beyond 'like'", 'Mailbag: Who Starts At RB? Is The Fifth WR On The Roster Right Now?', 'Warmongers declare themselves as God over other human beings – Carl Teichrib', 'Pluto coming out of Retrograde!', 'September 19, 20']
#
# -----
# Cluster label: com http www pr prnewswire newswire visit view html source
# ['Harwood Feffer LLP Announces Investigation of VASCO Data Security International, Inc.', 'Thanking Research and Hope honorees for their efforts fighting cancer', 'Potts Law Firm Files 90 New GM Ignition Switch Claims in St. Louis', 'Weleda Announces Partnership Benefiting Whole Kids Foundation', 'Local Happenings: Danville\'s Village Theatre presenting "Streetcar Named Desire" stage performance, film screening', "Virgin America Offers Free Uber Rides With Every Dallas Love Field Flight* And Brings 'Friday Night Flights' To The Big D", '20-Sep-2015 02:19', 'THE OPTIMISTIC FISHERMAN', 'Bella Thorne, Maddie Ziegler Hit Zac Posen Spring 2016 Fashion Show, NYFW', 'Target Steps Up Price-Matching']
#
# -----
# Cluster label: september india th news pm tuesday mumbai facebook day wednesday
# ['Police chiefs warn ministers Were too broke to go on the beat', "The Tom and Jerry Show: 'PM; Watson will run the Labour show while 'President' Corbyn carries on campaigning", 'PINK SLAMS DEMI?!', 'Week Four Friday Night Lights', 'Panelists say fewer births, marriages point to global demographic shift', 'Video - Jace Hymas 3rd Place - Bob Firman Invitational 2015', 'Awareness on e-roll & registration', 'Nursery celebrates six years since its opening', 'PDP celebrates Nigeria’s delisting from Polio endemic countries', 'Letter: Contact PUC re: Dakota Access Pipeline']
